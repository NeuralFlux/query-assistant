# %%
# %%bash
# declare -A endpoints=(
#     ["mygene"]="https://mygene.info/metadata/fields"
#     ["mychem"]="https://mychem.info/metadata/fields"
#     ["myvariant"]="https://myvariant.info/metadata/fields"
#     ["mydisease"]="https://mydisease.info/metadata/fields"
# );
#
# for service in "${!endpoints[@]}"; do
#     curl -X GET "${endpoints[$service]}" -o "data/schema/${service}_fields.json";
#     echo "Downloaded ${service} schema to data/schema/${service}_fields.json";
# done

# %%
import json
import os

directory = "data/schema"
schemas = {}

for filename in os.listdir(directory):
    if filename.endswith(".json"):
        key = os.path.splitext(filename)[0].replace("_fields", "")
        with open(os.path.join(directory, filename)) as fd:
            schemas[key] = json.load(fd)

for key, fields in schemas.items():
    print(f"{key}: {len(fields)} entries")
# Out:
# mychem: 1082 entries
# mygene: 355 entries
# mydisease: 264 entries
# myvariant: 1615 entries

# %%
version_map = {
    "mychem": "v1",
    "mygene": "v3",
    "mydisease": "v1",
    "myvariant": "v1"
}

# %%
# fields cannot be searched unless their schema is known, hence delete object fields
def remove_obj_fields(api_name: str, api_schema: dict):
    keys_to_del = []
    for key in api_schema:
        if api_schema[key]["type"] == "object":
            keys_to_del.append(key)

        # NOTE: can update prompt instead of using "type" every line
        # api_schema[key] = {"type": api_schema[key]["type"]}
    
    for key in keys_to_del:
        del api_schema[key]

    print(f"Deleted {len(keys_to_del)} fields, leaving {len(api_schema)} fields for {api_name}")

# %%
for api_name, api_schema in schemas.items():
    remove_obj_fields(api_name, api_schema)

print(f"\nMake sure dict was modified in place, len(mygene): {len(schemas["mygene"])}")
# Out:
# Deleted 145 fields, leaving 937 fields for mychem
# Deleted 75 fields, leaving 280 fields for mygene
# Deleted 40 fields, leaving 224 fields for mydisease
# Deleted 246 fields, leaving 1369 fields for myvariant
#
# Make sure dict was modified in place, len(mygene): 280

# %%
def minify_response(data: dict):
    assert isinstance(data, dict)
    for k, v in data.items():
        if isinstance(v, list) and len(v) > 1:
            data[k] = v[:1]
    return data

# %%
import httpx

endpoint_template = "https://{service}.info/{version}/query?size=1&fields=all&dotfield=true"

# manually curated ids for biggest record for each API, if needed
entity_ids = {
    "mychem": "AFCGFAGUEYAMAO-UHFFFAOYSA-N",  # InChIKey
    "mygene": "2146",  # short for NCBIGene:2146
    "mydisease": "0000845",  # short for MONDO:0000845
    "myvariant": "162741822G",  # short for chr1:g.162741822G>A
}
minified_responses = {}

with httpx.Client() as client:
    for service in schemas:
        url = endpoint_template.format(service=service, version=version_map[service])
        response = client.get(url)
        if response.status_code == 200:
            minified_responses[service] = minify_response(response.json()["hits"][0])
            print(f"Fetched and minified sample for {service}")
        else:
            print(f"Failed to fetch data for {service}, status code: {response.status_code}")
# Out:
# Fetched and minified sample for mychem
# Fetched and minified sample for mygene
# Fetched and minified sample for mydisease
# Fetched and minified sample for myvariant

# %%
schema_desc = {}

# %%
output_schema = {
    "type": "object",
    "properties": {
        "descriptions": {
            "type": "array",
            "items": {
                "type": "object",
                "properties": {
                    "field": {"type": "string"},
                    "description": {"type": "string"}
                },
                "required": ["field", "description"]
            }
        }
    },
    "required": ["descriptions"]
}

# %%
print(list(schemas["myvariant"].items()))
# Out:
# [('_seqhashed._flag', {'index': True, 'type': 'boolean'}), ('cadd.1000g.af', {'index': True, 'type': 'float'}), ('cadd.1000g.afr', {'index': False, 'type': 'float'}), ('cadd.1000g.amr', {'index': False, 'type': 'float'}), ('cadd.1000g.asn', {'index': False, 'type': 'float'}), ('cadd.1000g.eur', {'index': False, 'type': 'float'}), ('cadd.alt', {'analyzer': 'string_lowercase', 'index': True, 'type': 'text'}), ('cadd.anc', {'index': False, 'type': 'text'}), ('cadd.annotype', {'analyzer': 'string_lowercase', 'index': True, 'type': 'text'}), ('cadd.bstatistic', {'index': False, 'type': 'integer'}), ('cadd.chmm.bivflnk', {'index': False, 'type': 'float'}), ('cadd.chmm.enh', {'index': False, 'type': 'float'}), ('cadd.chmm.enhbiv', {'index': False, 'type': 'float'}), ('cadd.chmm.het', {'index': False, 'type': 'float'}), ('cadd.chmm.quies', {'index': False, 'type': 'float'}), ('cadd.chmm.reprpc', {'index': False, 'type': 'float'}), ('cadd.chmm.reprpcwk', {'index': False, 'type': 'float'}), ('cadd.chmm.tssa', {'index': False, 'type': 'float'}), ('cadd.chmm.tssaflnk', {'index': False, 'type': 'float'}), ('cadd.chmm.tssbiv', {'index': False, 'type': 'float'}), ('cadd.chmm.tx', {'index': False, 'type': 'float'}), ('cadd.chmm.txflnk', {'index': False, 'type': 'float'}), ('cadd.chmm.txwk', {'index': False, 'type': 'float'}), ('cadd.chmm.znfrpts', {'index': False, 'type': 'float'}), ('cadd.chrom', {'analyzer': 'string_lowercase', 'index': True, 'type': 'text'}), ('cadd.consdetail', {'analyzer': 'string_lowercase', 'index': True, 'type': 'text'}), ('cadd.consequence', {'analyzer': 'string_lowercase', 'index': True, 'type': 'text'}), ('cadd.consscore', {'index': True, 'type': 'integer'}), ('cadd.cpg', {'index': False, 'type': 'float'}), ('cadd.dna.helt', {'index': False, 'type': 'float'}), ('cadd.dna.mgw', {'index': False, 'type': 'float'}), ('cadd.dna.prot', {'index': False, 'type': 'float'}), ('cadd.dna.roll', {'index': False, 'type': 'float'}), ('cadd.dst2splice', {'index': True, 'type': 'integer'}), ('cadd.dst2spltype', {'analyzer': 'string_lowercase', 'index': True, 'type': 'text'}), ('cadd.encode.exp', {'index': False, 'type': 'float'}), ('cadd.encode.h3k27ac', {'index': False, 'type': 'float'}), ('cadd.encode.h3k4me1', {'index': False, 'type': 'float'}), ('cadd.encode.h3k4me3', {'index': False, 'type': 'float'}), ('cadd.encode.nucleo', {'index': False, 'type': 'float'}), ('cadd.encode.occ', {'index': False, 'type': 'integer'}), ('cadd.encode.p_val.comb', {'index': False, 'type': 'float'}), ('cadd.encode.p_val.ctcf', {'index': False, 'type': 'float'}), ('cadd.encode.p_val.dnas', {'index': False, 'type': 'float'}), ('cadd.encode.p_val.faire', {'index': False, 'type': 'float'}), ('cadd.encode.p_val.mycp', {'index': False, 'type': 'float'}), ('cadd.encode.p_val.polii', {'index': False, 'type': 'float'}), ('cadd.encode.sig.ctcf', {'index': False, 'type': 'float'}), ('cadd.encode.sig.dnase', {'index': False, 'type': 'float'}), ('cadd.encode.sig.faire', {'index': False, 'type': 'float'}), ('cadd.encode.sig.myc', {'index': False, 'type': 'float'}), ('cadd.encode.sig.polii', {'index': False, 'type': 'float'}), ('cadd.esp.af', {'index': True, 'type': 'float'}), ('cadd.esp.afr', {'index': False, 'type': 'float'}), ('cadd.esp.eur', {'index': False, 'type': 'float'}), ('cadd.exon', {'analyzer': 'string_lowercase', 'index': False, 'type': 'text'}), ('cadd.fitcons', {'index': False, 'type': 'float'}), ('cadd.gc', {'index': False, 'type': 'float'}), ('cadd.gene.ccds_id', {'analyzer': 'string_lowercase', 'index': False, 'type': 'text'}), ('cadd.gene.cds.cdna_pos', {'index': False, 'type': 'integer'}), ('cadd.gene.cds.cds_pos', {'index': False, 'type': 'integer'}), ('cadd.gene.cds.rel_cdna_pos', {'index': False, 'type': 'float'}), ('cadd.gene.cds.rel_cds_pos', {'index': False, 'type': 'float'}), ('cadd.gene.feature_id', {'analyzer': 'string_lowercase', 'index': False, 'type': 'text'}), ('cadd.gene.gene_id', {'analyzer': 'string_lowercase', 'index': True,  ...

# %%
minified_responses["myvariant"]
# Out:
# {'_id': 'chr6:g.30656453A>G',
#  '_score': 1.0,
#  'cadd._license': 'http://bit.ly/2TIuab9',
#  'cadd.alt': 'G',
#  'cadd.anc': 'A',
#  'cadd.annotype': 'CodingTranscript',
#  'cadd.bstatistic': 851,
#  'cadd.chmm.bivflnk': 0.0,
#  'cadd.chmm.enh': 0.055,
#  'cadd.chmm.enhbiv': 0.0,
#  'cadd.chmm.het': 0.0,
#  'cadd.chmm.quies': 0.0,
#  'cadd.chmm.reprpc': 0.0,
#  'cadd.chmm.reprpcwk': 0.0,
#  'cadd.chmm.tssa': 0.024,
#  'cadd.chmm.tssaflnk': 0.22,
#  'cadd.chmm.tssbiv': 0.0,
#  'cadd.chmm.tx': 0.0,
#  'cadd.chmm.txflnk': 0.047,
#  'cadd.chmm.txwk': 0.252,
#  'cadd.chmm.znfrpts': 0.0,
#  'cadd.chrom': 6,
#  'cadd.consdetail': 'synonymous',
#  'cadd.consequence': 'SYNONYMOUS',
#  'cadd.consscore': 5,
#  'cadd.cpg': 0.04,
#  'cadd.dna.helt': 0.65,
#  'cadd.dna.mgw': 0.15,
#  'cadd.dna.prot': 2.54,
#  'cadd.dna.roll': 1.48,
#  'cadd.encode.exp': 251.28,
#  'cadd.encode.h3k27ac': 49.96,
#  'cadd.encode.h3k4me1': 22.0,
#  'cadd.encode.h3k4me3': 38.8,
#  'cadd.encode.nucleo': 1.7,
#  'cadd.encode.occ': 3,
#  'cadd.encode.p_val.comb': 1.44,
#  'cadd.encode.p_val.ctcf': 5.02,
#  'cadd.encode.p_val.dnas': 1.03,
#  'cadd.encode.p_val.faire': 1.2,
#  'cadd.encode.p_val.mycp': 2.01,
#  'cadd.encode.p_val.polii': 3.36,
#  'cadd.encode.sig.ctcf': 0.3,
#  'cadd.encode.sig.dnase': 0.02,
#  'cadd.encode.sig.faire': 0.01,
#  'cadd.encode.sig.myc': 0.05,
#  'cadd.encode.sig.polii': 0.05,
#  'cadd.exon': '5/5',
#  'cadd.fitcons': 0.655796,
#  'cadd.gc': 0.55,
#  'cadd.gene.ccds_id': 'CCDS4686.1',
#  'cadd.gene.cds.cdna_pos': 1126,
#  'cadd.gene.cds.cds_pos': 774,
#  'cadd.gene.cds.rel_cdna_pos': 0.64,
#  'cadd.gene.cds.rel_cds_pos': 0.98,
#  'cadd.gene.feature_id': 'ENST00000259953',
#  'cadd.gene.gene_id': 'ENSG00000137404',
#  'cadd.gene.genename': 'NRM',
#  'cadd.gene.prot.protpos': 258,
#  'cadd.gene.prot.rel_prot_pos': 0.98,
#  'cadd.gerp.n': 4.73,
#  'cadd.gerp.rs': 839,
#  'cadd.gerp.rs_pval': 1.07622e-91,
#  'cadd.gerp.s': -2.59,
#  'cadd.isderived': 'TRUE',
#  'cadd.isknownvariant': 'FALSE',
#  'cadd.istv': 'FALSE',
#  'cadd.length': 0,
#  'cadd.mapability.20bp': 1,
#  'cadd.mapability.35bp': 1,
#  'cadd.min_dist_tse': 624,
#  'cadd.min_dist_tss': 781,
#  'cadd.mutindex': -13,
#  'cadd.naa': 'D',
#  'cadd.oaa': 'D',
#  'cadd.phast_cons.mammalian': 0.821,
#  'cadd.phast_cons.primate': 0.931,
#  'cadd.phast_cons.vertebrate': 0.249,
#  'cadd.phred': 5.844,
#  'cadd.phylop.mammalian': -0.63,
#  'cadd.phylop.primate': 0.53,
#  'cadd.phylop.vertebrate': -0.356,
#  'cadd.pos': 30656453,
#  'cadd.rawscore': 0.315578,
#  'cadd.ref': 'A',
#  'cadd.segway': 'GM1',
#  'cadd.type': 'SNV',
#  'chrom': '6',
#  'dbsnp._license': 'http://bit.ly/2AqoLOc',
#  'dbsnp.alleles.allele': ['A'],
#  'dbsnp.alleles.freq.gnomad_exomes': [1.0],
#  'dbsnp.alt': 'G',
#  'dbsnp.chrom': '6',
#  'dbsnp.dbsnp_build': 156,
#  'dbsnp.gene.geneid': [11270],
#  'dbsnp.gene.is_pseudo': [],
#  'dbsnp.gene.name': ['nurim'],
#  'dbsnp.gene.rnas.codon_aligned_transcript_change.deleted_sequence': ['GAT'],
#  'dbsnp.gene.rnas.codon_aligned_transcript_change.inserted_sequence': ['GAT'],
#  'dbsnp.gene.rnas.codon_aligned_transcript_change.position': [799],
#  'dbsnp.gene.rnas.codon_aligned_transcript_change.seq_id': ['NM_001270707.2'],
#  'dbsnp.gene.rnas.hgvs': ['NM_001270707.2:c.792='],
#  'dbsnp.gene.rnas.protein.variant.spdi.deleted_sequence': ['D'],
#  'dbsnp.gene.rnas.protein.variant.spdi.inserted_sequence': ['D'],
#  'dbsnp.gene.rnas.protein.variant.spdi.position': [263],
#  'dbsnp.gene.rnas.protein.variant.spdi.seq_id': ['NP_001257636.1'],
#  'dbsnp.gene.rnas.protein_product.refseq': ['NP_001257636.1'],
#  'dbsnp.gene.rnas.refseq': ['NM_001270707.2'],
#  'dbsnp.gene.rnas.so.accession': ['SO:0001580'],
#  'dbsnp.gene.rnas.so.name': ['coding_sequence_variant'],
#  'dbsnp.gene.strand': ['-'],
#  'dbsnp.gene.symbol': ['NRM'],
#  'dbsnp.gene.so.accession': 'SO:0001636',
#  'dbsnp.gene.so.name': '2KB_upstream_variant',
#  'dbsnp.hg19.end': 30656453,
#  'dbsnp.hg19.start': 30656453,
#  'dbsnp.ref': 'A',
#  'dbsnp.rsid': 'rs1354735987',
#  'dbsnp.vartype': 'snv',
#  'gnomad_exome._license': 'http://bit.ly/2I1cl1I',
#  'gnomad_exome.ac.ac': 1,
#  'gnomad_exome.ac.ac_afr': 0,
#  'gnomad_exome.ac.ac_afr_female': 0,
#  'gnomad_exome.ac.ac_afr_male': 0,
#  'gnomad_exome.ac.ac_amr': 0,
#  'gnomad_exome.ac.ac_amr_female': 0,
#  'gnomad_exome.ac.ac_amr_male': 0,
#  'gnomad_exome.ac.ac_asj': 0,
#  'gnomad_exome.ac.ac_asj_female': 0,
#  'gnomad_exome.ac.ac_asj_male': 0,
#  'gnomad_exome.ac.ac_eas': 0,
#  'gnomad_exome.ac.ac_eas_female': 0,
#  'gnomad_exome.ac.ac_eas_jpn': 0,
#  'gnomad_exome.ac.ac_eas_kor': 0,
#  'gnomad_exome.ac.ac_eas_male': 0,
#  'gnomad_exome.ac.ac_eas_oea': 0,
#  'gnomad_exome.ac.ac_female': 0,
#  'gnomad_exome.ac.ac_fin': 0,
#  'gnomad_exome.ac.ac_fin_female': 0,
#  'gnomad_exome.ac.ac_fin_male': 0,
#  'gnomad_exome.ac.ac_male': 1,
#  'gnomad_exome.ac.ac_nfe': 0,
#  'gnomad_exome.ac.ac_nfe_bgr': 0,
#  'gnomad_exome.ac.ac_nfe_est': 0,
#  'gnomad_exome.ac.ac_nfe_female': 0,
#  'gnomad_exome.ac.ac_nfe_male': 0,
#  'gnomad_exome.ac.ac_nfe_nwe': 0,
#  'gnomad_exome.ac.ac_nfe_onf': 0,
#  'gnomad_exome.ac.ac_nfe_seu': 0,
#  'gnomad_exome.ac.ac_nfe_swe': 0,
#  'gnomad_exome.ac.ac_oth': 0,
#  'gnomad_exome.ac.ac_oth_female': 0,
#  'gnomad_exome.ac.ac_oth_male': 0,
#  'gnomad_exome.ac.ac_sas': 1,
#  'gnomad_exome.ac.ac_sas_female': 0,
#  'gnomad_exome.ac.ac_sas_male': 1,
#  'gnomad_exome.af.af': 3.9867e-06,
#  'gnomad_exome.af.af_afr': 0.0,
#  'gnomad_exome.af.af_afr_female': 0.0,
#  'gnomad_exome.af.af_afr_male': 0.0,
#  'gnomad_exome.af.af_amr': 0.0,
#  'gnomad_exome.af.af_amr_female': 0.0,
#  'gnomad_exome.af.af_amr_male': 0.0,
#  'gnomad_exome.af.af_asj': 0.0,
#  'gnomad_exome.af.af_asj_female': 0.0,
#  'gnomad_exome.af.af_asj_male': 0.0,
#  'gnomad_exome.af.af_eas': 0.0,
#  'gnomad_exome.af.af_eas_female': 0.0,
#  'gnomad_exome.af.af_eas_jpn': 0.0,
#  'gnomad_exome.af.af_eas_kor': 0.0,
#  'gnomad_exome.af.af_eas_male': 0.0,
#  'gnomad_exome.af.af_eas_oea': 0.0,
#  'gnomad_exome.af.af_female': 0.0,
#  'gnomad_exome.af.af_fin': 0.0,
#  'gnomad_exome.af.af_fin_female': 0.0,
#  'gnomad_exome.af.af_fin_male': 0.0,
#  'gnomad_exome.af.af_male': 7.368e-06,
#  'gnomad_exome.af.af_nfe': 0.0,
#  'gnomad_exome.af.af_nfe_bgr': 0.0,
#  'gnomad_exome.af.af_nfe_est': 0.0,
#  'gnomad_exome.af.af_nfe_female': 0.0,
#  'gnomad_exome.af.af_nfe_male': 0.0,
#  'gnomad_exome.af.af_nfe_nwe': 0.0,
#  'gnomad_exome.af.af_nfe_onf': 0.0,
#  'gnomad_exome.af.af_nfe_seu': 0.0,
#  'gnomad_exome.af.af_nfe_swe': 0.0,
#  'gnomad_exome.af.af_oth': 0.0,
#  'gnomad_exome.af.af_oth_female': 0.0,
#  'gnomad_exome.af.af_oth_male': 0.0,
#  'gnomad_exome.af.af_sas': 3.26669e-05,
#  'gnomad_exome.af.af_sas_female': 0.0,
#  'gnomad_exome.af.af_sas_male': 4.33501e-05,
#  'gnomad_exome.alleles': 'G',
#  'gnomad_exome.alt': 'G',
#  'gnomad_exome.an.an': 250834,
#  'gnomad_exome.an.an_afr': 16004,
#  'gnomad_exome.an.an_afr_female': 9820,
#  'gnomad_exome.an.an_afr_male': 6184,
#  'gnomad_exome.an.an_amr': 34558,
#  'gnomad_exome.an.an_amr_female': 20252,
#  'gnomad_exome.an.an_amr_male': 14306,
#  'gnomad_exome.an.an_asj': 10032,
#  'gnomad_exome.an.an_asj_female': 4884,
#  'gnomad_exome.an.an_asj_male': 5148,
#  'gnomad_exome.an.an_eas': 18394,
#  'gnomad_exome.an.an_eas_female': 9328,
#  'gnomad_exome.an.an_eas_jpn': 152,
#  'gnomad_exome.an.an_eas_kor': 3818,
#  'gnomad_exome.an.an_eas_male': 9066,
#  'gnomad_exome.an.an_eas_oea': 14424,
#  'gnomad_exome.an.an_female': 115112,
#  'gnomad_exome.an.an_fin': 21614,
#  'gnomad_exome.an.an_fin_female': 10352,
#  'gnomad_exome.an.an_fin_male': 11262,
#  'gnomad_exome.an.an_male': 135722,
#  'gnomad_exome.an.an_nfe': 113508,
#  'gnomad_exome.an.an_nfe_bgr': 2670,
#  'gnomad_exome.an.an_nfe_est': 242,
#  'gnomad_exome.an.an_nfe_female': 50024,
#  'gnomad_exome.an.an_nfe_male': 63484,
#  'gnomad_exome.an.an_nfe_nwe': 42112,
#  'gnomad_exome.an.an_nfe_onf': 30888,
#  'gnomad_exome.an.an_nfe_seu': 11476,
#  'gnomad_exome.an.an_nfe_swe': 26120,
#  'gnomad_exome.an.an_oth': 6112,
#  'gnomad_exome.an.an_oth_female': 2908,
#  'gnomad_exome.an.an_oth_male': 3204,
#  'gnomad_exome.an.an_sas': 30612,
#  'gnomad_exome.an.an_sas_female': 7544,
#  'gnomad_exome.an.an_sas_male': 23068,
#  'gnomad_exome.baseqranksum': -2.958,
#  'gnomad_exome.chrom': '6',
#  'gnomad_exome.clippingranksum': 0.693,
#  'gnomad_exome.dp': 8528066,
#  'gnomad_exome.fs': 0.0,
#  'gnomad_exome.hom.hom': 0,
#  'gnomad_exome.hom.hom_afr': 0,
#  'gnomad_exome.hom.hom_afr_female': 0,
#  'gnomad_exome.hom.hom_afr_male': 0,
#  'gnomad_exome.hom.hom_amr': 0,
#  'gnomad_exome.hom.hom_amr_female': 0,
#  'gnomad_exome.hom.hom_amr_male': 0,
#  'gnomad_exome.hom.hom_asj': 0,
#  'gnomad_exome.hom.hom_asj_female': 0,
#  'gnomad_exome.hom.hom_asj_male': 0,
#  'gnomad_exome.hom.hom_eas': 0,
#  'gnomad_exome.hom.hom_eas_female': 0,
#  'gnomad_exome.hom.hom_eas_jpn': 0,
#  'gnomad_exome.hom.hom_eas_kor': 0,
#  'gnomad_exome.hom.hom_eas_male': 0,
#  'gnomad_exome.hom.hom_eas_oea': 0,
#  'gnomad_exome.hom.hom_female': 0,
#  'gnomad_exome.hom.hom_fin': 0,
#  'gnomad_exome.hom.hom_fin_female': 0,
#  'gnomad_exome.hom.hom_fin_male': 0,
#  'gnomad_exome.hom.hom_male': 0,
#  'gnomad_exome.hom.hom_nfe': 0,
#  'gnomad_exome.hom.hom_nfe_bgr': 0,
#  'gnomad_exome.hom.hom_nfe_est': 0,
#  'gnomad_exome.hom.hom_nfe_female': 0,
#  'gnomad_exome.hom.hom_nfe_male': 0,
#  'gnomad_exome.hom.hom_nfe_nwe': 0,
#  'gnomad_exome.hom.hom_nfe_onf': 0,
#  'gnomad_exome.hom.hom_nfe_seu': 0,
#  'gnomad_exome.hom.hom_nfe_swe': 0,
#  'gnomad_exome.hom.hom_oth': 0,
#  'gnomad_exome.hom.hom_oth_female': 0,
#  'gnomad_exome.hom.hom_oth_male': 0,
#  'gnomad_exome.hom.hom_sas': 0,
#  'gnomad_exome.hom.hom_sas_female': 0,
#  'gnomad_exome.hom.hom_sas_male': 0,
#  'gnomad_exome.inbreedingcoeff': 0.0076,
#  'gnomad_exome.mq.mq': 59.5,
#  'gnomad_exome.mq.mqranksum': 0.297,
#  'gnomad_exome.pab_max': 0.882996,
#  'gnomad_exome.pos': 30656453,
#  'gnomad_exome.qd': 11.46,
#  'gnomad_exome.readposranksum': -0.363,
#  'gnomad_exome.ref': 'A',
#  'gnomad_exome.rf': 0.867571,
#  'gnomad_exome.rsid': 'rs1354735987',
#  'gnomad_exome.sor': 0.613,
#  'gnomad_exome.type': 'snp',
#  'gnomad_exome.vqslod': 0.492,
#  'gnomad_exome.vqsr_culprit': 'FS',
#  'hg19.end': 30656453,
#  'hg19.start': 30656453,
#  'observed': True,
#  'snpeff._license': 'http://bit.ly/2suyRKt',
#  'snpeff.ann.cdna.length': ['1576'],
#  'snpeff.ann.cdna.position': ['947'],
#  'snpeff.ann.cds.length': ['807'],
#  'snpeff.ann.cds.position': ['792'],
#  'snpeff.ann.effect': ['synonymous_variant'],
#  'snpeff.ann.feature_id': ['NM_001270707.1'],
#  'snpeff.ann.feature_type': ['transcript'],
#  'snpeff.ann.gene_id': ['NRM'],
#  'snpeff.ann.genename': ['NRM'],
#  'snpeff.ann.hgvs_c': ['c.792T>C'],
#  'snpeff.ann.hgvs_p': ['p.Asp264Asp'],
#  'snpeff.ann.protein.length': ['268'],
#  'snpeff.ann.protein.position': ['264'],
#  'snpeff.ann.putative_impact': ['LOW'],
#  'snpeff.ann.rank': ['4'],
#  'snpeff.ann.total': ['4'],
#  'snpeff.ann.transcript_biotype': ['protein_coding'],
#  'snpeff.ann.distance_to_feature': ['1365'],
#  'vcf.alt': 'G',
#  'vcf.position': '30656453',
#  'vcf.ref': 'A'}

# %%
from openai import OpenAI

openai_client = OpenAI()

def describe_fields(fields: dict, sample_record: dict):
    """Call the OpenAI API to describe the keys."""
    
    response = openai_client.beta.chat.completions.parse(
        model="gpt-4o",
        messages=[
            {
                "role": "system",
                "content": "You are an expert in computational biology. Use the example given as reference for the task."
            },
            {
                "role": "user",
                "content": "Using your experience, describe the following fields from a biology database that aggregates data from various sources. Strictly output a JSON.\n" + json.dumps(fields) + "\n\nHere's a sample record\n" + json.dumps(sample_record)
            }
        ],
        response_format={
            "type": "json_schema",
            "json_schema": {
                "name": "field_description",
                "schema": output_schema
            }
        }
    )
    return response.choices[0].message.content

# %%
d = {
   "category": "Defines the classification of the entry, categorizing it into specific groups.",
   "compounds.annotation_quality": "Indicates the quality or reliability of the compound's annotation, such as 'high' or 'low'.",
   "compounds.cas_number": "The unique numerical identifier assigned to the chemical substance by the Chemical Abstracts Service (CAS).",
   "compounds.description": "A textual description of the compound, including its sources, occurrences, and properties.",
   "compounds.kingdom": "The broader classification of the compound within organic or inorganic categories.",
   "compounds.klass": "A mid-level classification of the compound, often referring to its chemical family.",
   "compounds.moldb_inchi": "The International Chemical Identifier (InChI) representation of the compound's structure.",
   "compounds.moldb_inchikey": "A hashed version of the InChI that serves as a unique identifier for the compound.",
   "compounds.moldb_iupac": "The IUPAC (International Union of Pure and Applied Chemistry) systematic name of the compound.",
   "compounds.moldb_mono_mass": "The monoisotopic mass of the compound, representing its exact atomic weight.",
   "compounds.moldb_smiles": "The SMILES (Simplified Molecular Input Line Entry System) string representation of the compound's molecular structure.",
   "compounds.name": "The common or widely recognized name of the compound.",
   "compounds.orig_contents.avg": "The average concentration of the compound found in a given source (e.g., food item).",
   "compounds.orig_contents.max": "The maximum recorded concentration of the compound in a given source.",
   "compounds.orig_contents.min": "The minimum recorded concentration of the compound in a given source.",
   "compounds.orig_contents.unit": "The unit of measurement for the compound's concentration, such as mg/100 g.",
   "compounds.reference": "The source or reference database from which the compound information was obtained.",
   "compounds.state": "The physical state of the compound (e.g., solid, liquid, gas) under standard conditions.",
   "compounds.subklass": "A more specific subclassification within the broader chemical class.",
   "compounds.superklass": "The highest-level chemical classification that the compound belongs to.",
   "created_at": "The timestamp indicating when the database entry was created.",
   "creator_id": "The unique identifier of the user or system that created the entry.",
   "description": "A general description of the database entry, including its biological or ecological significance.",
   "export_to_afcdb": "A boolean flag indicating whether the entry is included in the AFCDB (a specific food composition database).",
   "export_to_foodb": "A boolean flag indicating whether the entry is included in FooDB (a food chemistry database).",
   "food_group": "The broad category of food to which the entry belongs (e.g., 'Herbs and Spices').",
   "food_subgroup": "A more specific categorization within the food group (e.g., 'Herbs').",
   "food_type": "A classification of the food type, often used for database organization.",
   "itis_id": "The Integrated Taxonomic Information System (ITIS) identifier for the biological species.",
   "legacy_id": "An older identifier used in previous database versions.",
   "name": "The common or vernacular name of the entry.",
   "name_scientific": "The scientific or Latin name of the biological entity.",
   "ncbi_taxonomy_id": "The National Center for Biotechnology Information (NCBI) Taxonomy ID for the species.",
   "picture_content_type": "The MIME type of the associated image file (e.g., 'image/jpeg').",
   "picture_file_name": "The file name of the associated image.",
   "picture_file_size": "The size of the image file in bytes.",
   "picture_updated_at": "The timestamp indicating the last update of the associated image file.",
   "updated_at": "The timestamp indicating the last modification of the database entry.",
   "updater_id": "The unique identifier of the user or system that last updated the entry.",
   "wikipedia_id": "The Wikipedia page title or identifier associated with the entry."
}

# %%
f = {
    "category":{
       "index":True,
       "type":"keyword"
    },
    "compounds.annotation_quality":{
       "index":True,
       "type":"keyword"
    },
    "compounds.cas_number":{
       "index":True,
       "type":"text"
    },
    "compounds.description":{
       "index":True,
       "type":"text"
    },
    "compounds.kingdom":{
       "index":True,
       "type":"text"
    },
    "compounds.klass":{
       "index":True,
       "type":"text"
    },
    "compounds.moldb_inchi":{
       "index":True,
       "type":"keyword"
    },
    "compounds.moldb_inchikey":{
       "index":True,
       "type":"keyword"
    },
    "compounds.moldb_iupac":{
       "index":True,
       "type":"text"
    },
    "compounds.moldb_mono_mass":{
       "index":True,
       "type":"keyword"
    },
    "compounds.moldb_smiles":{
       "index":True,
       "type":"keyword"
    },
    "compounds.name":{
       "index":True,
       "type":"text"
    },
    "compounds.orig_contents.avg":{
       "index":True,
       "type":"float"
    },
    "compounds.orig_contents.max":{
       "index":True,
       "type":"float"
    },
    "compounds.orig_contents.min":{
       "index":True,
       "type":"float"
    },
    "compounds.orig_contents.unit":{
       "index":True,
       "type":"text"
    },
    "compounds.reference":{
       "index":True,
       "type":"text"
    },
    "compounds.state":{
       "index":True,
       "type":"keyword"
    },
    "compounds.subklass":{
       "index":True,
       "type":"text"
    },
    "compounds.superklass":{
       "index":True,
       "type":"text"
    },
    "created_at":{
       "index":True,
       "type":"keyword"
    },
    "creator_id":{
       "index":True,
       "type":"integer"
    },
    "description":{
       "index":True,
       "type":"text"
    },
    "export_to_afcdb":{
       "index":True,
       "type":"boolean"
    },
    "export_to_foodb":{
       "index":True,
       "type":"boolean"
    },
    "food_group":{
       "index":True,
       "type":"text"
    },
    "food_subgroup":{
       "index":True,
       "type":"text"
    },
    "food_type":{
       "index":True,
       "type":"text"
    },
    "itis_id":{
       "index":True,
       "type":"keyword"
    },
    "legacy_id":{
       "index":True,
       "type":"integer"
    },
    "name":{
       "index":True,
       "searched_by_default":True,
       "type":"text"
    },
    "name_scientific":{
       "index":True,
       "type":"text"
    },
    "ncbi_taxonomy_id":{
       "index":True,
       "type":"integer"
    },
    "picture_content_type":{
       "index":True,
       "type":"keyword"
    },
    "picture_file_name":{
       "index":True,
       "type":"keyword"
    },
    "picture_file_size":{
       "index":True,
       "type":"integer"
    },
    "picture_updated_at":{
       "index":True,
       "type":"keyword"
    },
    "updated_at":{
       "index":True,
       "type":"keyword"
    },
    "updater_id":{
       "index":True,
       "type":"integer"
    },
    "wikipedia_id":{
       "index":True,
       "type":"text"
    }
 }

# %%
f
# Out:
# {'category': {'type': 'keyword',
#   'description': 'A general description of the database entry, including its biological or ecological significance.'},
#  'compounds.annotation_quality': {'type': 'keyword',
#   'description': 'A general description of the database entry, including its biological or ecological significance.'},
#  'compounds.cas_number': {'type': 'text',
#   'description': 'A general description of the database entry, including its biological or ecological significance.'},
#  'compounds.description': {'type': 'text',
#   'description': 'A general description of the database entry, including its biological or ecological significance.'},
#  'compounds.kingdom': {'type': 'text',
#   'description': 'A general description of the database entry, including its biological or ecological significance.'},
#  'compounds.klass': {'type': 'text',
#   'description': 'A general description of the database entry, including its biological or ecological significance.'},
#  'compounds.moldb_inchi': {'type': 'keyword',
#   'description': 'A general description of the database entry, including its biological or ecological significance.'},
#  'compounds.moldb_inchikey': {'type': 'keyword',
#   'description': 'A general description of the database entry, including its biological or ecological significance.'},
#  'compounds.moldb_iupac': {'type': 'text',
#   'description': 'A general description of the database entry, including its biological or ecological significance.'},
#  'compounds.moldb_mono_mass': {'type': 'keyword',
#   'description': 'A general description of the database entry, including its biological or ecological significance.'},
#  'compounds.moldb_smiles': {'type': 'keyword',
#   'description': 'A general description of the database entry, including its biological or ecological significance.'},
#  'compounds.name': {'type': 'text',
#   'description': 'A general description of the database entry, including its biological or ecological significance.'},
#  'compounds.orig_contents.avg': {'type': 'float',
#   'description': 'A general description of the database entry, including its biological or ecological significance.'},
#  'compounds.orig_contents.max': {'type': 'float',
#   'description': 'A general description of the database entry, including its biological or ecological significance.'},
#  'compounds.orig_contents.min': {'type': 'float',
#   'description': 'A general description of the database entry, including its biological or ecological significance.'},
#  'compounds.orig_contents.unit': {'type': 'text',
#   'description': 'A general description of the database entry, including its biological or ecological significance.'},
#  'compounds.reference': {'type': 'text',
#   'description': 'A general description of the database entry, including its biological or ecological significance.'},
#  'compounds.state': {'type': 'keyword',
#   'description': 'A general description of the database entry, including its biological or ecological significance.'},
#  'compounds.subklass': {'type': 'text',
#   'description': 'A general description of the database entry, including its biological or ecological significance.'},
#  'compounds.superklass': {'type': 'text',
#   'description': 'A general description of the database entry, including its biological or ecological significance.'},
#  'created_at': {'type': 'keyword',
#   'description': 'A general description of the database entry, including its biological or ecological significance.'},
#  'creator_id': {'type': 'integer',
#   'description': 'A general description of the database entry, including its biological or ecological significance.'},
#  'description': {'type': 'text',
#   'description': 'A general description of the database entry, including its biological or ecological significance.'},
#  'export_to_afcdb': {'type': 'boolean',
#   'description': 'A general description of the database entry, including its biological or ecological significance.'},
#  'export_to_foodb': {'type': 'boolean',
#   'description': 'A general description of the database entry, including its biological or ecological significance.'},
#  'food_group': {'type': 'text',
#   'description': 'A general description of the database entry, including its biological or ecological significance.'},
#  'food_subgroup': {'type': 'text',
#   'description': 'A general description of the database entry, including its biological or ecological significance.'},
#  'food_type': {'type': 'text',
#   'description': 'A general description of the database entry, including its biological or ecological significance.'},
#  'itis_id': {'type': 'keyword',
#   'description': 'A general description of the database entry, including its biological or ecological significance.'},
#  'legacy_id': {'type': 'integer',
#   'description': 'A general description of the database entry, including its biological or ecological significance.'},
#  'name': {'searched_by_default': True,
#   'type': 'text',
#   'description': 'A general description of the database entry, including its biological or ecological significance.'},
#  'name_scientific': {'type': 'text',
#   'description': 'A general description of the database entry, including its biological or ecological significance.'},
#  'ncbi_taxonomy_id': {'type': 'integer',
#   'description': 'A general description of the database entry, including its biological or ecological significance.'},
#  'picture_content_type': {'type': 'keyword',
#   'description': 'A general description of the database entry, including its biological or ecological significance.'},
#  'picture_file_name': {'type': 'keyword',
#   'description': 'A general description of the database entry, including its biological or ecological significance.'},
#  'picture_file_size': {'type': 'integer',
#   'description': 'A general description of the database entry, including its biological or ecological significance.'},
#  'picture_updated_at': {'type': 'keyword',
#   'description': 'A general description of the database entry, including its biological or ecological significance.'},
#  'updated_at': {'type': 'keyword',
#   'description': 'A general description of the database entry, including its biological or ecological significance.'},
#  'updater_id': {'type': 'integer',
#   'description': 'A general description of the database entry, including its biological or ecological significance.'},
#  'wikipedia_id': {'type': 'text',
#   'description': 'A general description of the database entry, including its biological or ecological significance.'}}

# %%
import itertools
import time
import tqdm

def get_schema_descriptions(schema, sample_record):
    descriptions = []
    BATCH_SIZE = 100
    
    key_list = list(schema.keys())
    for idx in tqdm.tqdm(range(0, len(key_list), BATCH_SIZE)):
        batch = {k: schema[k] for k in key_list[idx:(idx + BATCH_SIZE)]}
        resp = json.loads(describe_fields(batch, sample_record))
        # resp = describe_fields(batch, sample_record)
        descriptions.extend(resp["descriptions"][:])
    
        time.sleep(1)
    return descriptions

# %%
schema_desc["myvariant"] = get_schema_descriptions(schemas["myvariant"], minified_responses["myvariant"])
# Out:
# 100%|█████████████████████████████████████████████████████████████| 14/14 [13:27<00:00, 57.69s/it]

# %%
print(json.dumps(schema_desc["myvariant"], indent=2))
# Out:
# [
#   {
#     "field": "_seqhashed._flag",
#     "description": "A boolean flag indicating some form of sequence hashing has been performed. It is indexed for fast lookup."
#   },
#   {
#     "field": "cadd.1000g.af",
#     "description": "The allele frequency of this variant in the 1000 Genomes Project dataset. It is represented as a floating point and indexed for queries."
#   },
#   {
#     "field": "cadd.1000g.afr",
#     "description": "The allele frequency of this variant within the African population according to the 1000 Genomes Project. It is a floating-point value but not indexed."
#   },
#   {
#     "field": "cadd.1000g.amr",
#     "description": "The allele frequency of this variant within the American populations in the 1000 Genomes Project. This is a float and not indexed."
#   },
#   {
#     "field": "cadd.1000g.asn",
#     "description": "The allele frequency of this variant in the Asian population according to the 1000 Genomes Project. Stored as a float and not indexed."
#   },
#   {
#     "field": "cadd.1000g.eur",
#     "description": "The allele frequency of this variant in the European population according to the 1000 Genomes Project. It is a float and not indexed."
#   },
#   {
#     "field": "cadd.alt",
#     "description": "The alternate allele for the mutation. Stored as text and indexed with a lowercase analyzer for consistent query performance."
#   },
#   {
#     "field": "cadd.anc",
#     "description": "The ancestral allele information stored as text, but not indexed for searching."
#   },
#   {
#     "field": "cadd.annotype",
#     "description": "The annotation type for this variant, stored as text processed through lowercase analyzer, and indexed."
#   },
#   {
#     "field": "cadd.bstatistic",
#     "description": "An integer value representing a statistical parameter related to the variant. It is not indexed."
#   },
#   {
#     "field": "cadd.chmm.bivflnk",
#     "description": "This represents the binary flanking regions state within a chromatin state model, stored as a float."
#   },
#   {
#     "field": "cadd.chmm.enh",
#     "description": "The enhancer state probability within a chromatin state model, stored as a float."
#   },
#   {
#     "field": "cadd.chmm.enhbiv",
#     "description": "The bivalent enhancer state probability within a chromatin state model, stored as a float."
#   },
#   {
#     "field": "cadd.chmm.het",
#     "description": "The heterochromatin state probability in a chromatin state model, stored as a float."
#   },
#   {
#     "field": "cadd.chmm.quies",
#     "description": "The quiescent chromatin state probability in a chromatin state model, stored as a float."
#   },
#   {
#     "field": "cadd.chmm.reprpc",
#     "description": "The Repressed PolyComb state probability in the chromatin state model, stored as a float."
#   },
#   {
#     "field": "cadd.chmm.reprpcwk",
#     "description": "The Weak Repressed PolyComb state probability in the chromatin state model, stored as a float."
#   },
#   {
#     "field": "cadd.chmm.tssa",
#     "description": "The Transcription Start Site Active state probability in a chromatin state model, stored as a float."
#   },
#   {
#     "field": "cadd.chmm.tssaflnk",
#     "description": "The Transcription Start Site Flanking active state probability, a part of chromatin modeling, stored as float."
#   },
#   {
#     "field": "cadd.chmm.tssbiv",
#     "description": "The Bi-Valent Transcription Start Site probability in a chromatin state model, stored as a float."
#   },
#   {
#     "field": "cadd.chmm.tx",
#     "description": "The transcription state probability in a chromatin state model, stored as a float."
#   },
#   {
#     "field": "cadd.chmm.txflnk",
#     "description": "The transcription flanking state probability in chromatin modeling, stored as a float."
#   },
#   {
#     "field": "cadd.chmm.txwk",
#     "description": "The weak transcription state probability within a chromatin state model, stored as a float."
#   },
#   {
#     "field": "cadd.chmm.znfrpts",
#     "description": "The repressed zinc finger protein state probability in chromatin modeling, stored as a float."
#   },
#   {
#     "field": "cadd.chrom",
#     "description": "The chromosome number or identifier where the variant is located, stored as lowercase text and indexed."
#   },
#   {
#     "field": "cadd.consdetail",
#     "description": "Details of the conservation score or related consensus information, stored as lowercase text and indexed."
#   },
#   {
#     "field": "cadd.consequence",
#     "description": "The consequence of the variant in a biological context, stored as lowercase text and indexed."
#   },
#   {
#     "field": "cadd.consscore",
#     "description": "An integer score representing the conservation impact of the variant, indexed for querying."
#   },
#   {
#     "field": "cadd.cpg",
#     "description": "The CpG content around the variant site, stored as a floating-point value, not indexed."
#   },
#   {
#     "field": "cadd.dna.helt",
#     "description": "DNA helix twist, reflecting certain structural properties stored as a float."
#   },
#   {
#     "field": "cadd.dna.mgw",
#     "description": "Minor groove width of the DNA in context of the variant, stored as a float."
#   },
#   {
#     "field": "cadd.dna.prot",
#     "description": "Intrinsically encoded parameters of DNA curvature, stored as a float."
#   },
#   {
#     "field": "cadd.dna.roll",
#     "description": "The roll angle degree of the DNA, stored as a float."
#   },
#   {
#     "field": "cadd.dst2splice",
#     "description": "The distance to the closest splice site, stored as an integer and indexed."
#   },
#   {
#     "field": "cadd.dst2spltype",
#     "description": "The type of splice site in terms of classification, stored as lowercase text and indexed."
#   },
#   {
#     "field": "cadd.encode.exp",
#     "description": "Expression levels from ENCODE datasets, stored as a float."
#   },
#   {
#     "field": "cadd.encode.h3k27ac",
#     "description": "The signal intensity for H3K27ac histone modification from ENCODE, stored as a float."
#   },
#   {
#     "field": "cadd.encode.h3k4me1",
#     "description": "The signal intensity for H3K4me1 histone mark from ENCODE, stored as a float."
#   },
#   {
#     "field": "cadd.encode.h3k4me3",
#     "description": "The signal intensity for H3K4me3 histone modification from ENCODE, stored as a float."
#   },
#   {
#     "field": "cadd.encode.nucleo",
#     "description": "The nucleosome occupancy score from ENCODE, stored as a float."
#   },
#   {
#     "field": "cadd.encode.occ",
#     "description": "An integer representing the degree of chromatin accessibility from ENCODE data."
#   },
#   {
#     "field": "cadd.encode.p_val.comb",
#     "description": "The combined p-value score for peak overlaps and matches, stored as a float."
#   },
#   {
#     "field": "cadd.encode.p_val.ctcf",
#     "description": "The p-value score for CTCF binding sites from ENCODE data, stored as a float."
#   },
#   {
#     "field": "cadd.encode.p_val.dnas",
#     "description": "The p-value score for DNase I hypersensitivity sites, stored as a float."
#   },
#   {
#     "field": "cadd.encode.p_val.faire",
#     "description": "The p-value score for FAIRE-seq peaks from ENCODE, stored as a float."
#   },
#   {
#     "field": "cadd.encode.p_val.mycp",
#     "description": "The p-value for Myc protein binding from ENCODE data, stored as a float."
#   },
#   {
#     "field": "cadd.encode.p_val.polii",
#     "description": "The p-value of RNA polymerase II binding from ENCODE, stored as a float."
#   },
#   {
#     "field": "cadd.encode.sig.ctcf",
#     "description": "Signal intensity for CTCF sites from ENCODE, stored as a float."
#   },
#   {
#     "field": "cadd.encode.sig.dnase",
#     "description": "Signal strength for DNase hypersensitivity from ENCODE data, stored as a float."
#   },
#   {
#     "field": "cadd.encode.sig.faire",
#     "description": "Signal intensity for FAIRE-seq data indicating open chromatin, stored as a float."
#   },
#   {
#     "field": "cadd.encode.sig.myc",
#     "description": "Signal intensity for Myc binding from ENCODE datasets, stored as a float."
#   },
#   {
#     "field": "cadd.encode.sig.polii",
#     "description": "Signal intensity for RNA polymerase II activity from ENCODE data, stored as a float."
#   },
#   {
#     "field": "cadd.esp.af",
#     "description": "The allele frequency in the Exome Sequencing Project, stored as a float and indexed."
#   },
#   {
#     "field": "cadd.esp.afr",
#     "description": "The allele frequency specific to the African population in the Exome Sequencing Project, stored as a float."
#   },
#   {
#     "field": "cadd.esp.eur",
#     "description": "The allele frequency within the European population according to the Exome Sequencing Project, stored as a float."
#   },
#   {
#     "field": "cadd.exon",
#     "description": "Information about the exon, possibly position or identifier, stored as lowercase text."
#   },
#   {
#     "field": "cadd.fitcons",
#     "description": "The fitCons score which evaluates variants based on evolutionary conservation and other functional data, stored as a float."
#   },
#   {
#     "field": "cadd.gc",
#     "description": "The GC content around the region of the variant, stored as a floating point."
#   },
#   {
#     "field": "cadd.gene.ccds_id",
#     "description": "The Consensus CDS identification for tracing gene identifiers, stored as lowercase text."
#   },
#   {
#     "field": "cadd.gene.cds.cdna_pos",
#     "description": "The position of the variant in the coding DNA sequence, stored as an integer."
#   },
#   {
#     "field": "cadd.gene.cds.cds_pos",
#     "description": "The position of the variant in the coding sequence (CDS), given as an integer value."
#   },
#   {
#     "field": "cadd.gene.cds.rel_cdna_pos",
#     "description": "The relative position of the variant in the cDNA sequence, stored as a float."
#   },
#   {
#     "field": "cadd.gene.cds.rel_cds_pos",
#     "description": "The relative position of the variant within the coding sequence, stored as a float."
#   },
#   {
#     "field": "cadd.gene.feature_id",
#     "description": "Identifier of the gene feature, stored as lowercase text."
#   },
#   {
#     "field": "cadd.gene.gene_id",
#     "description": "The gene identifier possibly from a genomic database, stored as lowercase text and indexed."
#   },
#   {
#     "field": "cadd.gene.genename",
#     "description": "The name of the gene affected or associated with the variant, stored as lowercase searchable text."
#   },
#   {
#     "field": "cadd.gene.prot.domain",
#     "description": "Protein domain affected by the variant, stored as lowercase text indexed."
#   },
#   {
#     "field": "cadd.gene.prot.protpos",
#     "description": "The position of the variant on the protein sequence, stored as an integer."
#   },
#   {
#     "field": "cadd.gene.prot.rel_prot_pos",
#     "description": "Relative position of the variant on the protein sequence, stored as a float."
#   },
#   {
#     "field": "cadd.gerp.n",
#     "description": "A GERP conservation score, indicating evolutionary conserved sites, stored as an integer."
#   },
#   {
#     "field": "cadd.gerp.rs",
#     "description": "A GERP score reflecting the evolutionary constraint, stored as a float."
#   },
#   {
#     "field": "cadd.gerp.rs_pval",
#     "description": "The p-value of the GERP RS score, indicating statistical support for the conservation, stored as a float."
#   },
#   {
#     "field": "cadd.gerp.s",
#     "description": "A raw score from GERP indicating the strength of evolutionary conservation, stored as an integer."
#   },
#   {
#     "field": "cadd.grantham",
#     "description": "An integer representing Grantham score which measures chemical distance between amino acids, indexed."
#   },
#   {
#     "field": "cadd.intron",
#     "description": "Details about the intron region associated with the variant, stored as lowercase text."
#   },
#   {
#     "field": "cadd.isderived",
#     "description": "A boolean represented as text indicating if the variant is derived, not indexed."
#   },
#   {
#     "field": "cadd.isknownvariant",
#     "description": "A text field denoting if the variant is known according to existing data, stored in lowercase."
#   },
#   {
#     "field": "cadd.istv",
#     "description": "Text indicating if the variant is a transition or transversion, stored as lowercase."
#   },
#   {
#     "field": "cadd.length",
#     "description": "Integer indicating the length affected by the variant, not indexed."
#   },
#   {
#     "field": "cadd.mapability.20bp",
#     "description": "Mapability score using 20 base pair sequences, stored as a float."
#   },
#   {
#     "field": "cadd.mapability.35bp",
#     "description": "Mapability score using 35 base pair sequences, stored as a float."
#   },
#   {
#     "field": "cadd.min_dist_tse",
#     "description": "Minimum distance to the closest transcription end site, stored as an integer and indexed."
#   },
#   {
#     "field": "cadd.min_dist_tss",
#     "description": "Minimum distance to the closest transcription start site, stored as an integer and indexed."
#   },
#   {
#     "field": "cadd.mirsvr.aln",
#     "description": "Integer score related to miR binding site alignment, indicating potential alteration."
#   },
#   {
#     "field": "cadd.mirsvr.e",
#     "description": "Energy score related to miRNA interaction, stored as a float."
#   },
#   {
#     "field": "cadd.mirsvr.score",
#     "description": "A score from miR-SVR which predicts microRNA target impact, stored as a float."
#   },
#   {
#     "field": "cadd.motif.dist",
#     "description": "Distance metric associated with regulatory motif changes, stored as a float."
#   },
#   {
#     "field": "cadd.motif.ecount",
#     "description": "Integer count of matched motifs in a region around the variant."
#   },
#   {
#     "field": "cadd.motif.ehipos",
#     "description": "Motif high-impact position in lowercase text representing specific genetics impact."
#   },
#   {
#     "field": "cadd.motif.ename",
#     "description": "The name of the affected motif, stored as lowercase text."
#   },
#   {
#     "field": "cadd.motif.escorechng",
#     "description": "Change in motif score, indicative of biological disruption, stored as a float."
#   },
#   {
#     "field": "cadd.motif.toverlap",
#     "description": "Integer indicating overlap with known motifs in the region."
#   },
#   {
#     "field": "cadd.mutindex",
#     "description": "A computed mutation index on variant impact, stored as an integer."
#   },
#   {
#     "field": "cadd.naa",
#     "description": "Native amino acid, stored as lowercase text representation in peptide sequences."
#   },
#   {
#     "field": "cadd.oaa",
#     "description": "Observed amino acid post-mutation, stored as lowercase text."
#   },
#   {
#     "field": "cadd.phast_cons.mammalian",
#     "description": "PhastCon conservation score for mammals, indicating conservation level, stored as a float."
#   },
#   {
#     "field": "cadd.phast_cons.primate",
#     "description": "The PhastCon score for primates, suggesting evolutionary conservation, stored as float."
#   },
#   {
#     "field": "cadd.phast_cons.vertebrate",
#     "description": "A conservation score from PhastCons for vertebrates, stored as a float."
#   },
#   {
#     "field": "cadd.phred",
#     "description": "Phred score of the variant, indicating likelihood of a variant being real; stored as a float and indexed."
#   },
#   {
#     "field": "cadd.phylop.mammalian",
#     "description": "PhyloP score for mammalian sequences indicating evolutionary conservation, stored as a float."
#   },
#   {
#     "field": "cadd.phylop.primate",
#     "description": "A float value representing the phylogenetic p-value score for conservation among primates, from the CADD (Combined Annotation Dependent Depletion) database, used to predict the potential impact of variants."
#   },
#   {
#     "field": "cadd.phylop.vertebrate",
#     "description": "A float value indicating the phylogenetic p-value score for conservation among vertebrates, from the CADD database, used in assessing the impact of genetic variants."
#   },
#   {
#     "field": "cadd.polyphen.cat",
#     "description": "A categorical keyword representing the PolyPhen categorization of a variant's predicted impact on protein function, indexed for searchability."
#   },
#   {
#     "field": "cadd.polyphen.val",
#     "description": "A float value indicating the PolyPhen score, which predicts the potential impact of an amino acid substitution on protein structure and function, indexed for queries."
#   },
#   {
#     "field": "cadd.pos",
#     "description": "A long integer denoting the genomic position of the variant, indexed for database searchability."
#   },
#   {
#     "field": "cadd.rawscore",
#     "description": "A float value representing the CADD raw score, indicating the deleteriousness of a genetic variant without any scaling or adjustments."
#   },
#   {
#     "field": "cadd.ref",
#     "description": "Text indicating the reference allele in a lowercase format, indexed for easy retrieval and comparison against variants."
#   },
#   {
#     "field": "cadd.scoresegdup",
#     "description": "A float value indicating duplication score segments from CADD, which assess the likelihood of a variant being part of a segmental duplication, not indexed for queries."
#   },
#   {
#     "field": "cadd.segway",
#     "description": "Text describing the annotation from the Segway genomic annotation method, stored in lowercase for consistency but not indexed."
#   },
#   {
#     "field": "cadd.sift.cat",
#     "description": "A keyword category from the SIFT tool that predicts whether a substitution affects protein function, indexed for efficient lookups."
#   },
#   {
#     "field": "cadd.sift.val",
#     "description": "A float value from the SIFT tool indicating the likelihood of a change being tolerated, indexed for database queries on variant impact."
#   },
#   {
#     "field": "cadd.targetscans",
#     "description": "An integer indicating the target scan count, typically referring to the number of scanning experiments or validations done for this variant, not indexed."
#   },
#   {
#     "field": "cadd.tf.bs",
#     "description": "An integer indicative of the transcription factor binding sites affected by the variant, recorded for reference but not indexed."
#   },
#   {
#     "field": "cadd.tf.bs_peaks",
#     "description": "An integer showing the number of peak alterations in transcription factor binding caused by the variant, not indexed for searches."
#   },
#   {
#     "field": "cadd.tf.bs_peaks_max",
#     "description": "A float value representing the maximum peak change in transcription factor binding sites associated with the variant, not indexed."
#   },
#   {
#     "field": "cadd.type",
#     "description": "Text indicating the type of variant (e.g., SNV, deletion), indexed with a lowercase analyzer for easy and consistent searching."
#   },
#   {
#     "field": "cgi.association",
#     "description": "Text field storing known associations of the variant, possibly to diseases or traits, indexed for case-insensitive searches."
#   },
#   {
#     "field": "cgi.cdna",
#     "description": "Text representation of the variant's cDNA sequence, indexed with a lowercase analyzer for uniformity in queries."
#   },
#   {
#     "field": "cgi.drug",
#     "description": "Text indicating drugs possibly associated with the variant, indexed to facilitate finding related records in the database."
#   },
#   {
#     "field": "cgi.evidence_level",
#     "description": "Text description of the evidence strength supporting a variant's annotation, indexed for retrieval in searches."
#   },
#   {
#     "field": "cgi.gene",
#     "description": "Text indicating the gene symbol or name associated with this variant, indexed for consistent referencing."
#   },
#   {
#     "field": "cgi.primary_tumor_type",
#     "description": "Text field specifying the primary tumor type associated with the variant, indexed for retrieval based on user queries."
#   },
#   {
#     "field": "cgi.protein_change",
#     "description": "Text describing changes at the protein level due to the variant, indexed for systematic and quick lookup."
#   },
#   {
#     "field": "cgi.region",
#     "description": "Text representing the genomic region where the variant occurs, processed and stored in lowercase, indexed."
#   },
#   {
#     "field": "cgi.source",
#     "description": "Text indicating the source database or project providing the variant information, analyzed for case-insensitive searches."
#   },
#   {
#     "field": "cgi.transcript",
#     "description": "Text detailing the transcript associated with the variant, indexed and analyzed for lowercase storage and retrieval."
#   },
#   {
#     "field": "chrom",
#     "description": "Text field representing the chromosome on which the variant is located, standardized to lowercase for consistency and indexed for queries."
#   },
#   {
#     "field": "civic.allele_registry_id",
#     "description": "A keyword field indicating the unique identifier for the allele in a registry, indexed for effective search and reference."
#   },
#   {
#     "field": "civic.assertions.clinical_significance",
#     "description": "Text expressing the clinical significance of a variant within the CIViC (Clinical Interpretation of Variants in Cancer) database, indexed."
#   },
#   {
#     "field": "civic.assertions.description",
#     "description": "Text providing a detailed description of the CIViC assertion involving the variant, indexed for retrieval."
#   },
#   {
#     "field": "civic.assertions.disease.display_name",
#     "description": "Text displaying the disease name associated with the assertion, indexed for database search functionalities."
#   },
#   {
#     "field": "civic.assertions.disease.doid",
#     "description": "A keyword field containing the disease ontology identifier associated with the disease in the assertion, indexed."
#   },
#   {
#     "field": "civic.assertions.disease.id",
#     "description": "An integer representing the unique identifier for the disease in the assertion within the CIViC database, indexed for reference."
#   },
#   {
#     "field": "civic.assertions.disease.name",
#     "description": "Text indicating the disease name involved in the assertion, indexed for convenient search and retrieval."
#   },
#   {
#     "field": "civic.assertions.disease.url",
#     "description": "A keyword field holding the URL to the detailed disease information related to this assertion, indexed."
#   },
#   {
#     "field": "civic.assertions.drugs.id",
#     "description": "An integer providing the unique identifier for drugs associated with the assertion, indexed."
#   },
#   {
#     "field": "civic.assertions.drugs.name",
#     "description": "A keyword field for the drug name linked to the assertion, allowing indexed access for efficient searching."
#   },
#   {
#     "field": "civic.assertions.evidence_direction",
#     "description": "A keyword indicating the direction of the evidence in the assertion (e.g., supports, does not support), indexed."
#   },
#   {
#     "field": "civic.assertions.evidence_item_count",
#     "description": "An integer representing the number of evidence items supporting the assertion, indexed."
#   },
#   {
#     "field": "civic.assertions.evidence_type",
#     "description": "A keyword designating the type of evidence supporting the assertion, indexed for query purposes."
#   },
#   {
#     "field": "civic.assertions.fda_regulatory_approval",
#     "description": "A boolean indicating whether the assertion or associated evidence has received FDA regulatory approval, indexed for straightforward queries."
#   },
#   {
#     "field": "civic.assertions.gene.id",
#     "description": "An integer unique ID for the gene in the assertion, indexed for easy cross-referencing."
#   },
#   {
#     "field": "civic.assertions.gene.name",
#     "description": "A keyword identifier for the gene name within the assertion, indexed for efficient database retrieval operations."
#   },
#   {
#     "field": "civic.assertions.id",
#     "description": "An integer giving the unique ID for the assertion in the CIViC database, indexed for precise record-keeping and access."
#   },
#   {
#     "field": "civic.assertions.name",
#     "description": "A keyword field that provides the name or title of the assertion being made in the citation, indexed."
#   },
#   {
#     "field": "civic.assertions.open_change_count",
#     "description": "An integer showing the count of open changes or updates to the assertion, indexed for keeping track of revisions."
#   },
#   {
#     "field": "civic.assertions.pending_evidence_count",
#     "description": "An integer indicating the number of pending evidence items yet to be reviewed or verified, indexed."
#   },
#   {
#     "field": "civic.assertions.status",
#     "description": "A keyword field representing the current status of the assertion, indexed for ease of retrieval."
#   },
#   {
#     "field": "civic.assertions.summary",
#     "description": "Text providing a summary of the assertion, designed to be searchable and retrievable in textual queries."
#   },
#   {
#     "field": "civic.assertions.type",
#     "description": "A keyword describing the type of assertion (such as diagnostic, prognostic, predictive), indexed."
#   },
#   {
#     "field": "civic.assertions.variant.id",
#     "description": "An integer serving as the unique identifier for the variant involved in the assertion, indexed for accessible referencing."
#   },
#   {
#     "field": "civic.assertions.variant.name",
#     "description": "A keyword providing the variant name within the assertion, indexed to facilitate database querying."
#   },
#   {
#     "field": "civic.civic_actionability_score",
#     "description": "A float representing the score that indicates the actionability of a variant based on CIViC's criteria, indexed for relevance-based searching."
#   },
#   {
#     "field": "civic.clinvar_entries",
#     "description": "A keyword field listing the ClinVar entries related to the variant, indexed for database cross-referencing."
#   },
#   {
#     "field": "civic.coordinates.chromosome",
#     "description": "A keyword that identifies the chromosome involved in the CIViC coordinate entry, indexed."
#   },
#   {
#     "field": "civic.coordinates.chromosome2",
#     "description": "A keyword for the second chromosome if the variant involves a second chromosomal location, indexed."
#   },
#   {
#     "field": "civic.coordinates.ensembl_version",
#     "description": "An integer indicating the Ensembl database version used for coordinates, indexed for query specification."
#   },
#   {
#     "field": "civic.coordinates.reference_bases",
#     "description": "A keyword denoting the reference bases at a specific coordinate, indexed for variant mapping."
#   },
#   {
#     "field": "civic.coordinates.reference_build",
#     "description": "A keyword for the reference genome build (e.g., GRCh37, GRCh38), indexed for consistency in reference alignment."
#   },
#   {
#     "field": "civic.coordinates.representative_transcript",
#     "description": "A keyword identifying the representative transcript that the variant affects, indexed."
#   },
#   {
#     "field": "civic.coordinates.representative_transcript2",
#     "description": "A keyword for the secondary representative transcript if applicable, indexed."
#   },
#   {
#     "field": "civic.coordinates.start",
#     "description": "An integer marking the start position of the variant on the chromosome, indexed for precise mapping."
#   },
#   {
#     "field": "civic.coordinates.start2",
#     "description": "An integer for the start position on a secondary chromosome if pertinent, indexed."
#   },
#   {
#     "field": "civic.coordinates.stop",
#     "description": "An integer marking the stop position of the variant on the chromosome, indexed for location specificity."
#   },
#   {
#     "field": "civic.coordinates.stop2",
#     "description": "An integer for the stop position on a secondary chromosome if applicable, indexed."
#   },
#   {
#     "field": "civic.coordinates.variant_bases",
#     "description": "A keyword field for the variant bases at a given coordinate, indexed for accurate variant retrieval."
#   },
#   {
#     "field": "civic.description",
#     "description": "Text providing an overall description of the variant as it appears in the CIViC database, indexed for textual queries."
#   },
#   {
#     "field": "civic.entrez_id",
#     "description": "An integer corresponding to the Entrez ID of a gene associated with the variant, indexed for reference lookup."
#   },
#   {
#     "field": "civic.entrez_name",
#     "description": "A keyword depicting the gene name as registered in the Entrez database, indexed for quick retrieval."
#   },
#   {
#     "field": "civic.evidence_items.clinical_significance",
#     "description": "Text detailing the clinical significance of evidence items related to the variant, indexed for ease of search."
#   },
#   {
#     "field": "civic.evidence_items.description",
#     "description": "Text describing the evidence items, indexed for detailed query access."
#   },
#   {
#     "field": "civic.evidence_items.disease.display_name",
#     "description": "Text displaying the name of the disease associated with evidence items, indexed."
#   },
#   {
#     "field": "civic.evidence_items.disease.doid",
#     "description": "A keyword field for the disease ontology ID relevant to evidence items, indexed."
#   },
#   {
#     "field": "civic.evidence_items.disease.id",
#     "description": "An integer providing the ID for diseases relevant to evidence items, indexed."
#   },
#   {
#     "field": "civic.evidence_items.disease.name",
#     "description": "Text giving the disease name associated with evidence items, indexed for disease-specific queries."
#   },
#   {
#     "field": "civic.evidence_items.disease.url",
#     "description": "A keyword URL leading to the disease information relevant to the evidence items, indexed."
#   },
#   {
#     "field": "civic.evidence_items.drug_interaction_type",
#     "description": "A keyword describing the type of drug interaction with the variant or evidence item, indexed."
#   },
#   {
#     "field": "civic.evidence_items.drugs.id",
#     "description": "An integer indicating the ID for drugs involved in evidence items, indexed for direct reference."
#   },
#   {
#     "field": "civic.evidence_items.drugs.name",
#     "description": "Text providing names of drugs in connection with evidence items, indexed."
#   },
#   {
#     "field": "civic.evidence_items.evidence_direction",
#     "description": "Text identifying the direction (supporting or not supporting) of the evidence, indexed for retrieval."
#   },
#   {
#     "field": "civic.evidence_items.evidence_level",
#     "description": "A keyword depicting the evidence level supporting the evidence item, indexed."
#   },
#   {
#     "field": "civic.evidence_items.evidence_type",
#     "description": "A keyword categorizing the evidence type, indexed for descriptive queries."
#   },
#   {
#     "field": "civic.evidence_items.id",
#     "description": "An integer providing the ID for the evidence item, indexed for precise tracking and analysis."
#   },
#   {
#     "field": "civic.evidence_items.name",
#     "description": "A keyword giving the name or title of the evidence item, indexed to allow for searches."
#   },
#   {
#     "field": "civic.evidence_items.open_change_count",
#     "description": "An integer tracking the count of open changes for evidence items, indexed for monitoring."
#   },
#   {
#     "field": "civic.evidence_items.phenotypes.hpo_class",
#     "description": "Text indicating the Human Phenotype Ontology (HPO) class related to an evidence item, indexed."
#   },
#   {
#     "field": "civic.evidence_items.phenotypes.hpo_id",
#     "description": "A keyword for the HPO ID associated with phenotypes in the evidence items, indexed for queries."
#   },
#   {
#     "field": "civic.evidence_items.phenotypes.id",
#     "description": "An integer for the ID of phenotypes linked to evidence items, indexed."
#   },
#   {
#     "field": "civic.evidence_items.phenotypes.url",
#     "description": "A keyword containing the URL to phenotype information relevant to evidence items, indexed."
#   },
#   {
#     "field": "civic.evidence_items.rating",
#     "description": "An integer for the rating of evidence items, providing a metric for quality or strength, indexed."
#   },
#   {
#     "field": "civic.evidence_items.source.asco",
#     "description": "An integer that identifies ASCO abstract sources for evidence items, indexed for cross-referencing."
#   },
#   {
#     "field": "civic.evidence_items.source.asco_abstract_id",
#     "description": "An integer denoting the ID of ASCO abstracts cited as sources in evidence items, indexed."
#   },
#   {
#     "field": "civic.evidence_items.source.citation",
#     "description": "Text containing the citation details of sources for evidence items, indexed for comprehensive referencing."
#   },
#   {
#     "field": "civic.evidence_items.source.clinical_trials.clinical_trial_url",
#     "description": "A keyword storing URLs to clinical trials relevant to the evidence items, indexed."
#   },
#   {
#     "field": "civic.evidence_items.source.clinical_trials.description",
#     "description": "Text providing descriptions of clinical trials cited as sources, indexed."
#   },
#   {
#     "field": "civic.evidence_items.source.clinical_trials.name",
#     "description": "Text giving the name or title of the clinical trials used as sources, indexed."
#   },
#   {
#     "field": "civic.evidence_items.source.clinical_trials.nct_id",
#     "description": "A keyword representing the National Clinical Trial ID for referenced studies, indexed."
#   },
#   {
#     "field": "civic.evidence_items.source.full_journal_title",
#     "description": "Text containing the title of journals where studies related to the evidence items are published, indexed."
#   },
#   {
#     "field": "civic.evidence_items.source.id",
#     "description": "An integer for the ID of source publications about evidence items, indexed for precision."
#   },
#   {
#     "field": "civic.evidence_items.source.is_review",
#     "description": "A boolean indicating if the source for an evidence item is a review article, indexed for filtering searches."
#   },
#   {
#     "field": "civic.evidence_items.source.journal",
#     "description": "The name of the journal where the evidence item was published."
#   },
#   {
#     "field": "civic.evidence_items.source.name",
#     "description": "The name of the source from which the evidence item originates."
#   },
#   {
#     "field": "civic.evidence_items.source.open_access",
#     "description": "A boolean indicating if the source of the evidence item is open access."
#   },
#   {
#     "field": "civic.evidence_items.source.pmc_id",
#     "description": "The PubMed Central ID for the source of the evidence item."
#   },
#   {
#     "field": "civic.evidence_items.source.publication_date.day",
#     "description": "The day of the month when the source of the evidence item was published."
#   },
#   {
#     "field": "civic.evidence_items.source.publication_date.month",
#     "description": "The month when the source of the evidence item was published."
#   },
#   {
#     "field": "civic.evidence_items.source.publication_date.year",
#     "description": "The year when the source of the evidence item was published."
#   },
#   {
#     "field": "civic.evidence_items.source.pubmed",
#     "description": "The PubMed ID of the source where the evidence item was published."
#   },
#   {
#     "field": "civic.evidence_items.source.source_url",
#     "description": "The URL linking to the source of the evidence item."
#   },
#   {
#     "field": "civic.evidence_items.source.status",
#     "description": "The status of the source, indicating its review or publication status."
#   },
#   {
#     "field": "civic.evidence_items.status",
#     "description": "The current status of the evidence item, reflecting its validation or acceptance level."
#   },
#   {
#     "field": "civic.evidence_items.type",
#     "description": "The type of evidence item, detailing the nature of evidence provided."
#   },
#   {
#     "field": "civic.evidence_items.variant_id",
#     "description": "The ID corresponding to the variant associated with the evidence item."
#   },
#   {
#     "field": "civic.evidence_items.variant_origin",
#     "description": "The origin of the variant related to the evidence item, such as somatic or germline."
#   },
#   {
#     "field": "civic.gene_id",
#     "description": "The unique identifier for the gene associated within the CIViC database."
#   },
#   {
#     "field": "civic.hgvs_expressions",
#     "description": "HGVS expressions associated with the variant or evidence item."
#   },
#   {
#     "field": "civic.name",
#     "description": "The name of the entry or record within the CIViC database."
#   },
#   {
#     "field": "civic.provisional_values.description.revision_id",
#     "description": "The ID of the revision linked to the provisional value's description."
#   },
#   {
#     "field": "civic.provisional_values.description.value",
#     "description": "The description text for the provisional value within CIViC."
#   },
#   {
#     "field": "civic.sources.citation",
#     "description": "The citation text for a source, formatted for reference."
#   },
#   {
#     "field": "civic.sources.citation_id",
#     "description": "A unique identifier for the citation within the CIViC database."
#   },
#   {
#     "field": "civic.sources.full_journal_title",
#     "description": "The full title of the journal from which the source is taken."
#   },
#   {
#     "field": "civic.sources.id",
#     "description": "A unique identifier for a source within the CIViC collection."
#   },
#   {
#     "field": "civic.sources.is_review",
#     "description": "A boolean indicating if the source is a review article."
#   },
#   {
#     "field": "civic.sources.journal",
#     "description": "Short form or abbreviation of the journal name for a source."
#   },
#   {
#     "field": "civic.sources.name",
#     "description": "The name of the source, possibly the article title or source title."
#   },
#   {
#     "field": "civic.sources.open_access",
#     "description": "A boolean indicating whether the source is open access."
#   },
#   {
#     "field": "civic.sources.pmc_id",
#     "description": "The identifier for the source in the PubMed Central repository."
#   },
#   {
#     "field": "civic.sources.publication_date.day",
#     "description": "The day of publication for the source referenced."
#   },
#   {
#     "field": "civic.sources.publication_date.month",
#     "description": "The month of publication for the source referenced."
#   },
#   {
#     "field": "civic.sources.publication_date.year",
#     "description": "The year of publication for the source referenced."
#   },
#   {
#     "field": "civic.sources.source_type",
#     "description": "The type of source, indicating whether it's a journal article, book, etc."
#   },
#   {
#     "field": "civic.sources.source_url",
#     "description": "URL where the source can be accessed online."
#   },
#   {
#     "field": "civic.sources.status",
#     "description": "Status of the source, such as published, in review, etc."
#   },
#   {
#     "field": "civic.type",
#     "description": "Type identifier within the CIViC database, marking the nature of the data entry."
#   },
#   {
#     "field": "civic.variant_aliases",
#     "description": "Alternative names or aliases for the variant in question."
#   },
#   {
#     "field": "civic.variant_groups.description",
#     "description": "Description of the variant group within which the variant falls."
#   },
#   {
#     "field": "civic.variant_groups.id",
#     "description": "Identifier for the variant group the variant belongs to."
#   },
#   {
#     "field": "civic.variant_groups.name",
#     "description": "Name of the variant group for classification purposes."
#   },
#   {
#     "field": "civic.variant_groups.type",
#     "description": "Type of variant group, likely a predefined category type."
#   },
#   {
#     "field": "civic.variant_groups.variants.civic_actionability_score",
#     "description": "Score assessing the clinical actionability of the variant in CIViC."
#   },
#   {
#     "field": "civic.variant_groups.variants.coordinates.chromosome",
#     "description": "The chromosome location for the variant."
#   },
#   {
#     "field": "civic.variant_groups.variants.coordinates.chromosome2",
#     "description": "The second chromosome involved if the variant spans multiple loci."
#   },
#   {
#     "field": "civic.variant_groups.variants.coordinates.ensembl_version",
#     "description": "Version of the Ensembl database for referencing variant coordinates."
#   },
#   {
#     "field": "civic.variant_groups.variants.coordinates.reference_bases",
#     "description": "Reference nucleotides at the variant location."
#   },
#   {
#     "field": "civic.variant_groups.variants.coordinates.reference_build",
#     "description": "Reference genome build used for variant mapping."
#   },
#   {
#     "field": "civic.variant_groups.variants.coordinates.representative_transcript",
#     "description": "Transcript chosen to represent the variant coordinates."
#   },
#   {
#     "field": "civic.variant_groups.variants.coordinates.representative_transcript2",
#     "description": "Second representative transcript if applicable."
#   },
#   {
#     "field": "civic.variant_groups.variants.coordinates.start",
#     "description": "Start position of the variant on the chromosome."
#   },
#   {
#     "field": "civic.variant_groups.variants.coordinates.start2",
#     "description": "Second start position if the variant has a secondary locus."
#   },
#   {
#     "field": "civic.variant_groups.variants.coordinates.stop",
#     "description": "Stop position of the variant on the chromosome."
#   },
#   {
#     "field": "civic.variant_groups.variants.coordinates.stop2",
#     "description": "Second stop position if the variant encompasses multiple loci."
#   },
#   {
#     "field": "civic.variant_groups.variants.coordinates.variant_bases",
#     "description": "Base changes in the variant."
#   },
#   {
#     "field": "civic.variant_groups.variants.description",
#     "description": "Textual description of the particular variant."
#   },
#   {
#     "field": "civic.variant_groups.variants.entrez_id",
#     "description": "Entrez Gene ID associated with this variant."
#   },
#   {
#     "field": "civic.variant_groups.variants.entrez_name",
#     "description": "Standardized name of the gene from Entrez database linked to variant."
#   },
#   {
#     "field": "civic.variant_groups.variants.gene_id",
#     "description": "Unique identifier for the gene associated with the variant."
#   },
#   {
#     "field": "civic.variant_groups.variants.id",
#     "description": "Unique identifier for the variant within the variant group."
#   },
#   {
#     "field": "civic.variant_groups.variants.name",
#     "description": "Name or label given to the variant."
#   },
#   {
#     "field": "civic.variant_groups.variants.type",
#     "description": "Type classification of the variant."
#   },
#   {
#     "field": "civic.variant_groups.variants.variant_types.description",
#     "description": "Description of the variant type."
#   },
#   {
#     "field": "civic.variant_groups.variants.variant_types.display_name",
#     "description": "Display-friendly version of the variant type's name."
#   },
#   {
#     "field": "civic.variant_groups.variants.variant_types.id",
#     "description": "Unique identifier for the variant type in the system."
#   },
#   {
#     "field": "civic.variant_groups.variants.variant_types.name",
#     "description": "Common name for this type of variant."
#   },
#   {
#     "field": "civic.variant_groups.variants.variant_types.so_id",
#     "description": "Sequence Ontology identifier for the variant type."
#   },
#   {
#     "field": "civic.variant_groups.variants.variant_types.url",
#     "description": "URL linking to additional information about the variant type."
#   },
#   {
#     "field": "civic.variant_id",
#     "description": "Identifier for a specific variant in the CIViC dataset."
#   },
#   {
#     "field": "civic.variant_types.description",
#     "description": "General description of the variant's type."
#   },
#   {
#     "field": "civic.variant_types.display_name",
#     "description": "User-friendly display name for the variant type."
#   },
#   {
#     "field": "civic.variant_types.id",
#     "description": "Internal identifier used for variant type classification."
#   },
#   {
#     "field": "civic.variant_types.name",
#     "description": "Name that classifies the variant under a specific type."
#   },
#   {
#     "field": "civic.variant_types.so_id",
#     "description": "ID from the Sequence Ontology that classifies the variant type."
#   },
#   {
#     "field": "civic.variant_types.url",
#     "description": "Link to web resource for more information on the variant type."
#   },
#   {
#     "field": "clinvar.allele_id",
#     "description": "Identifier for the allele linked to the clinvar record."
#   },
#   {
#     "field": "clinvar.alt",
#     "description": "The alternative allele identifier, often used in comparative genetics."
#   },
#   {
#     "field": "clinvar.chrom",
#     "description": "Chromosome location identifier for the variant in ClinVar."
#   },
#   {
#     "field": "clinvar.coding_hgvs_only",
#     "description": "Boolean flag indicating if only coding HGVS notations are present."
#   },
#   {
#     "field": "clinvar.cosmic",
#     "description": "Information related to the Cosmic database entry associated."
#   },
#   {
#     "field": "clinvar.cytogenic",
#     "description": "Cytogenic information or annotation related to the ClinVar record."
#   },
#   {
#     "field": "clinvar.dbvar",
#     "description": "Entries or annotations from dbVar database linked to the record."
#   },
#   {
#     "field": "clinvar.gene.id",
#     "description": "Long integer ID of the gene as per the ClinVar record."
#   },
#   {
#     "field": "clinvar.gene.symbol",
#     "description": "Symbol of the gene in ClinVar, usually the standardized abbreviation."
#   },
#   {
#     "field": "clinvar.genotypeset.genotype",
#     "description": "Genotype information set, indicating genetic configuration in ClinVar."
#   },
#   {
#     "field": "clinvar.genotypeset.type",
#     "description": "Type categorization for the genotype within the ClinVar database."
#   },
#   {
#     "field": "clinvar.hg19.end",
#     "description": "Ending position on chromosome for the variant under hg19 genome assembly."
#   },
#   {
#     "field": "clinvar.hg19.start",
#     "description": "Start position on chromosome for the variant under hg19 assembly."
#   },
#   {
#     "field": "clinvar.hg38.end",
#     "description": "Ending position on chromosome for the variant under hg38 genome assembly."
#   },
#   {
#     "field": "clinvar.hg38.start",
#     "description": "Start position on chromosome for the variant under hg38 assembly."
#   },
#   {
#     "field": "clinvar.hgvs.coding",
#     "description": "HGVS notation for coding regions in ClinVar records."
#   },
#   {
#     "field": "clinvar.hgvs.genomic",
#     "description": "Genomic representation of the variant using HGVS notation."
#   },
#   {
#     "field": "clinvar.hgvs.non-coding",
#     "description": "Non-coding region HGVS notation in ClinVar records."
#   },
#   {
#     "field": "clinvar.hgvs.protein",
#     "description": "Protein level variant representation using HGVS notation."
#   },
#   {
#     "field": "clinvar.omim",
#     "description": "OMIM database reference information linked to ClinVar entry."
#   },
#   {
#     "field": "clinvar.rcv.accession",
#     "description": "Accession number for the RCV entry in ClinVar."
#   },
#   {
#     "field": "clinvar.rcv.clinical_significance",
#     "description": "Assessment of clinical significance for RCV entry in ClinVar."
#   },
#   {
#     "field": "clinvar.rcv.conditions.age_of_onset",
#     "description": "Age of onset for conditions associated with the ClinVar entry."
#   },
#   {
#     "field": "clinvar.rcv.conditions.identifiers.efo",
#     "description": "EFO (Experimental Factor Ontology) identifiers linked to conditions."
#   },
#   {
#     "field": "clinvar.rcv.conditions.identifiers.gene",
#     "description": "Gene identifiers related to the conditions in ClinVar."
#   },
#   {
#     "field": "clinvar.rcv.conditions.identifiers.human_phenotype_ontology",
#     "description": "Identifiers from Human Phenotype Ontology relevant to conditions."
#   },
#   {
#     "field": "clinvar.rcv.conditions.identifiers.medgen",
#     "description": "MedGen identifiers, indicating associated medical genetics terms."
#   },
#   {
#     "field": "clinvar.rcv.conditions.identifiers.mesh",
#     "description": "This field contains identifiers for medical subject headings (MeSH) associated with conditions in a ClinVar record. MeSH provides a standardized way to retrieve information that may use different terminology for the same concepts."
#   },
#   {
#     "field": "clinvar.rcv.conditions.identifiers.mondo",
#     "description": "This field holds identifiers from the MONDO Disease Ontology system for conditions related to ClinVar records. MONDO aims to unify multiple disease nomenclature systems into a single coherent ontology."
#   },
#   {
#     "field": "clinvar.rcv.conditions.identifiers.omim",
#     "description": "This field includes identifiers from the Online Mendelian Inheritance in Man (OMIM) database, which catalog human genes and genetic phenotypes, focusing on the relationship between phenotype and genotype."
#   },
# ...
#   },
#   {
#     "field": "grasp.in_mirna",
#     "description": "Indicator if the variant is within a miRNA region according to GRASP."
#   },
#   {
#     "field": "grasp.in_mirna_bs",
#     "description": "Indicator if the variant is within a miRNA binding site according to GRASP."
#   },
#   {
#     "field": "grasp.includes_male_female_only_analyses",
#     "description": "Indicates whether the analyses include only male or female subjects as per GRASP."
#   },
#   {
#     "field": "grasp.initial_sample_description",
#     "description": "Description of initial sample cohorts in GRASP study."
#   },
#   {
#     "field": "grasp.nearest_gene",
#     "description": "Name of the gene closest to the variant as per GRASP data."
#   },
#   {
#     "field": "grasp.oreg_anno",
#     "description": "Annotations from ORegAnno indicating regulatory elements close to the variant in GRASP."
#   },
#   {
#     "field": "grasp.platform_snps_passing_qc",
#     "description": "Platform-specific SNPs that passed quality control checks in GRASP studies."
#   },
#   {
#     "field": "grasp.polyphen2",
#     "description": "PolyPhen-2 scores used for predicting possible impact of variants in GRASP data."
#   },
#   {
#     "field": "grasp.publication.journal",
#     "description": "Journal where the findings associated with the variant were published as per GRASP."
#   },
#   {
#     "field": "grasp.publication.location_within_paper",
#     "description": "Specific location details of the variant within a published paper in GRASP."
#   },
#   {
#     "field": "grasp.publication.p_value",
#     "description": "P-value of the variant's association from a published study as per GRASP."
#   },
#   {
#     "field": "grasp.publication.paper_phenotype_categories",
#     "description": "Categories of phenotypes covered by a published GRASP study."
#   },
#   {
#     "field": "grasp.publication.paper_phenotype_description",
#     "description": "Detailed description of phenotypes covered by a published GRASP study."
#   },
#   {
#     "field": "grasp.publication.phenotype",
#     "description": "Phenotype associated with the variant in a study according to GRASP."
#   },
#   {
#     "field": "grasp.publication.pmid",
#     "description": "PubMed ID (PMID) for a publication associated with the variant in GRASP."
#   },
#   {
#     "field": "grasp.publication.snpid",
#     "description": "SNP ID used in publications relating to GRASP studies."
#   },
#   {
#     "field": "grasp.publication.title",
#     "description": "Title of the publication reporting the variant in GRASP."
#   },
#   {
#     "field": "grasp.replication.african",
#     "description": "Count of individuals of African descent in the replication phase of a GRASP study."
#   },
#   {
#     "field": "grasp.replication.arab_me",
#     "description": "Count of individuals of Arab or Middle Eastern descent in the replication phase of a GRASP study."
#   },
#   {
#     "field": "grasp.replication.east_asian",
#     "description": "Count of individuals of East Asian descent in the replication phase of a GRASP study."
#   },
#   {
#     "field": "grasp.replication.european",
#     "description": "Count of individuals of European descent in the replication phase of a GRASP study."
#   },
#   {
#     "field": "grasp.replication.filipino",
#     "description": "Count of Filipino individuals in the replication phase of a GRASP study."
#   },
#   {
#     "field": "grasp.replication.hispanic",
#     "description": "Count of Hispanic individuals in the replication phase of a GRASP study."
#   },
#   {
#     "field": "grasp.replication.indian_south_asian",
#     "description": "Count of individuals from South Asian regions, particularly Indian, in a GRASP replication study."
#   },
#   {
#     "field": "grasp.replication.indonesian",
#     "description": "Count of Indonesian individuals in the replication phase of a GRASP study."
#   },
#   {
#     "field": "grasp.replication.micronesian",
#     "description": "Count of Micronesian individuals in the replication phase of a GRASP study."
#   },
#   {
#     "field": "grasp.replication.mixed",
#     "description": "Count of individuals with mixed ancestry in the replication phase of a GRASP study."
#   },
#   {
#     "field": "grasp.replication.native",
#     "description": "Count of Native American individuals in the replication phase of a GRASP study."
#   },
#   {
#     "field": "grasp.replication.total_samples",
#     "description": "The total number of samples used in the replication phase of a study, indexed for searchability and stored as an integer."
#   },
#   {
#     "field": "grasp.replication.unspecified",
#     "description": "The number of unspecified samples used in the replication phase of a study, indexed for searchability and stored as an integer."
#   },
#   {
#     "field": "grasp.replication_sample_description",
#     "description": "A text description of the replication samples used in a study, stored in lowercase for uniform searching purposes."
#   },
#   {
#     "field": "grasp.rna_edit",
#     "description": "Information related to RNA editing events, stored as lowercase text for easy retrieval."
#   },
#   {
#     "field": "grasp.sift",
#     "description": "The SIFT score or detail related to a particular genetic variant, stored in lowercase for search consistency."
#   },
#   {
#     "field": "grasp.srsid",
#     "description": "An identifier, such as an SRS ID, stored as a long integer, and indexed to allow efficient querying."
#   },
#   {
#     "field": "grasp.uniprot",
#     "description": "The UniProt protein identifier associated with the genetic data, stored in lowercase text for search purposes."
#   },
#   {
#     "field": "gwassnps.genename",
#     "description": "The name of the gene associated with a single nucleotide polymorphism (SNP), stored as lowercase text for searchability."
#   },
#   {
#     "field": "gwassnps.pubmed",
#     "description": "The PubMed ID(s) referencing the study where the SNP was identified, stored as a keyword."
#   },
#   {
#     "field": "gwassnps.pvalue",
#     "description": "The p-value indicating the statistical significance of the SNP's association with a trait, stored as a float but not directly indexed."
#   },
#   {
#     "field": "gwassnps.pvalue_desc",
#     "description": "A textual description of the p-value, stored as text for interpretative purposes, but not indexed."
#   },
#   {
#     "field": "gwassnps.region",
#     "description": "The genomic region where the SNP is located, analyzed and stored as lowercase text for efficient searches."
#   },
#   {
#     "field": "gwassnps.risk_allele",
#     "description": "The allele associated with increased risk for the trait being studied, stored as text and indexed for easy lookup."
#   },
#   {
#     "field": "gwassnps.risk_allele_freq",
#     "description": "The frequency of the risk allele in the studied population, stored as a float and indexed for query."
#   },
#   {
#     "field": "gwassnps.rsid",
#     "description": "The reference SNP ID (rsID) used by databases such as dbSNP, stored as lowercase text and searchable by default."
#   },
#   {
#     "field": "gwassnps.title",
#     "description": "The title of the publication or study from which the SNP data is derived, stored as searchable text."
#   },
#   {
#     "field": "gwassnps.trait",
#     "description": "The trait associated with the identified SNP, stored as text and indexed for searching."
#   },
#   {
#     "field": "hg19.end",
#     "description": "The genomic end position of a variant on the human reference genome version hg19, represented as an integer."
#   },
#   {
#     "field": "hg19.start",
#     "description": "The genomic start position of a variant on the human reference genome version hg19, represented as an integer."
#   },
#   {
#     "field": "mutdb.alt",
#     "description": "The alternative allele found in a mutation database for a particular variant, stored as lowercase text for consistency."
#   },
#   {
#     "field": "mutdb.chrom",
#     "description": "The chromosome number or identifier found in mutation databases, stored as lowercase text for searching."
#   },
#   {
#     "field": "mutdb.cosmic_id",
#     "description": "The COSMIC ID for a variant found in the COSMIC mutation database, stored as lowercase text."
#   },
#   {
#     "field": "mutdb.hg19.end",
#     "description": "The end position of a mutation on the human genome version hg19, stored as an integer."
#   },
#   {
#     "field": "mutdb.hg19.start",
#     "description": "The start position of a mutation on the human genome version hg19, stored as an integer."
#   },
#   {
#     "field": "mutdb.mutpred_score",
#     "description": "A score predicting the impact of a mutation, recorded as a double for precision."
#   },
#   {
#     "field": "mutdb.ref",
#     "description": "The reference allele as per mutation databases, stored in lowercase to maintain consistency."
#   },
#   {
#     "field": "mutdb.rsid",
#     "description": "The reference SNP ID (rsID) used for a variant in mutation databases, stored in lowercase and searchable by default."
#   },
#   {
#     "field": "mutdb.strand",
#     "description": "The genomic strand (positive or negative) on which the mutation is located, stored as a keyword."
#   },
#   {
#     "field": "mutdb.uniprot_id",
#     "description": "The UniProt ID for a protein related to the mutation, indexed as lowercase text for easy search."
#   },
#   {
#     "field": "observed",
#     "description": "A boolean value indicating whether a particular event or variation has been observed."
#   },
#   {
#     "field": "snpedia.text",
#     "description": "Textual information stored in SNPedia, a wiki supporting personal genomics, stored as searchable text."
#   },
#   {
#     "field": "snpeff.ann.cdna.length",
#     "description": "The length of the complementary DNA (cDNA) segment as annotated by SnpEff, stored as an integer."
#   },
#   {
#     "field": "snpeff.ann.cdna.position",
#     "description": "The specific position within the cDNA related to the annotated effect by SnpEff, stored as an integer."
#   },
#   {
#     "field": "snpeff.ann.cds.length",
#     "description": "The length of the coding sequence (CDS) as annotated by SnpEff, stored as an integer."
#   },
#   {
#     "field": "snpeff.ann.cds.position",
#     "description": "The position within the CDS as annotated by SnpEff, stored as an integer for precise analysis."
#   },
#   {
#     "field": "snpeff.ann.effect",
#     "description": "The predicted effect of a variant on gene function or expression as annotated by SnpEff, stored as lowercase text."
#   },
#   {
#     "field": "snpeff.ann.feature_id",
#     "description": "An identifier for the feature (e.g., a transcript) affected by the variant, stored in lowercase text."
#   },
#   {
#     "field": "snpeff.ann.feature_type",
#     "description": "The type of feature (e.g., transcript, exon) that the variant affects, annotated by SnpEff, stored in lowercase text."
#   },
#   {
#     "field": "snpeff.ann.gene_id",
#     "description": "The gene ID related to the effect of the variant as annotated by SnpEff, stored in lowercase text for searchability."
#   },
#   {
#     "field": "snpeff.ann.genename",
#     "description": "The name of the gene associated with the variant, annotated by SnpEff and stored as lowercase text."
#   },
#   {
#     "field": "snpeff.ann.hgvs_c",
#     "description": "The HGVS notation for the change at the cDNA level, as annotated by SnpEff, stored in lowercase text."
#   },
#   {
#     "field": "snpeff.ann.hgvs_p",
#     "description": "The HGVS notation for the change at the protein level, as annotated by SnpEff, stored in lowercase text."
#   },
#   {
#     "field": "snpeff.ann.protein.length",
#     "description": "The length of the protein affected by the variant, as annotated by SnpEff, stored as an integer."
#   },
#   {
#     "field": "snpeff.ann.protein.position",
#     "description": "The position of the amino acid change within the protein, as determined by SnpEff, stored as an integer."
#   },
#   {
#     "field": "snpeff.ann.putative_impact",
#     "description": "The inferred impact level of the variant on protein function (e.g., high, moderate, low), as annotated by SnpEff."
#   },
#   {
#     "field": "snpeff.ann.rank",
#     "description": "The rank of the functional annotation as determined by SnpEff, stored as an integer."
#   },
#   {
#     "field": "snpeff.ann.total",
#     "description": "The total number of effects a variant has been annotated with by SnpEff, stored as an integer."
#   },
#   {
#     "field": "snpeff.ann.transcript_biotype",
#     "description": "The type of transcript (e.g., protein-coding, non-coding) as annotated by SnpEff, stored in lowercase text."
#   },
#   {
#     "field": "snpeff.ann.distance_to_feature",
#     "description": "The distance from the variant to a specific genomic feature, as annotated by SnpEff, stored as an integer."
#   },
#   {
#     "field": "snpeff.lof.gene_id",
#     "description": "The gene ID for a loss-of-function variant as predicted by SnpEff, stored as lowercase text for searchability."
#   },
#   {
#     "field": "snpeff.lof.genename",
#     "description": "The name of the gene associated with a loss-of-function variant, stored as lowercase text."
#   },
#   {
#     "field": "snpeff.lof.number_of_transcripts_in_gene",
#     "description": "The total number of transcripts present in the gene predicted to have a loss-of-function variant by SnpEff."
#   },
#   {
#     "field": "snpeff.lof.percent_of_transcripts_affected",
#     "description": "The percentage of transcripts affected within a gene predicted to experience loss-of-function by SnpEff."
#   },
#   {
#     "field": "snpeff.nmd.gene_id",
#     "description": "The gene ID associated with a variant predicted to undergo nonsense-mediated decay by SnpEff, stored as lowercase text."
#   },
#   {
#     "field": "snpeff.nmd.genename",
#     "description": "The name of the gene associated with a variant predicted to undergo nonsense-mediated decay by SnpEff, stored in lowercase text."
#   },
#   {
#     "field": "snpeff.nmd.number_of_transcripts_in_gene",
#     "description": "The number of transcripts within the gene that are subject to nonsense-mediated decay, as predicted by SnpEff."
#   },
#   {
#     "field": "snpeff.nmd.percent_of_transcripts_affected",
#     "description": "The percentage of transcripts within a gene affected by nonsense-mediated decay, as predicted by SnpEff."
#   },
#   {
#     "field": "vcf.alt",
#     "description": "The alternative allele in a variant call format (VCF) file, stored in lowercase text for search purposes."
#   },
#   {
#     "field": "vcf.position",
#     "description": "The specific genomic position of a variant as recorded in a VCF file, stored as an integer."
#   },
#   {
#     "field": "vcf.ref",
#     "description": "The reference allele in a VCF file, stored as lowercase text for uniformity in searching."
#   },
#   {
#     "field": "wellderly.alleles.allele",
#     "description": "Alternative alleles present in the Wellderly dataset, stored in lowercase to maintain search uniformity."
#   },
#   {
#     "field": "wellderly.alleles.freq",
#     "description": "Frequency of alleles within the Wellderly dataset, numeric representation as a float and indexed for search."
#   },
#   {
#     "field": "wellderly.alt",
#     "description": "The alternative allele within the Wellderly study dataset, stored in lowercase text for consistency."
#   },
#   {
#     "field": "wellderly.chrom",
#     "description": "The chromosomal location identifier within the Wellderly dataset, stored in lowercase for search efficiency."
#   },
#   {
#     "field": "wellderly.hg19.end",
#     "description": "The genomic end position according to hg19 coordinates in the Wellderly dataset, stored as an integer."
#   },
#   {
#     "field": "wellderly.hg19.start",
#     "description": "The genomic start position according to hg19 coordinates in the Wellderly dataset, stored as an integer."
#   },
#   {
#     "field": "wellderly.pos",
#     "description": "The position of the variant within the Wellderly dataset, considered as a long integer for larger values."
#   },
#   {
#     "field": "wellderly.ref",
#     "description": "The reference allele within the Wellderly dataset, stored in lowercase text for search uniformity."
#   },
#   {
#     "field": "wellderly.vartype",
#     "description": "The variant type categorization within the Wellderly dataset, stored in lowercase to ensure search consistency."
#   }
# ]

# %%
for api_name in schemas:
    print("Could not summarize the following for", api_name)
    desc_set = {d["field"] for d in schema_desc[api_name]}
    print(set(schemas[api_name].keys()).difference(desc_set))
# Out:
# Could not summarize the following for mychem
# set()
# Could not summarize the following for mygene
# set()
# Could not summarize the following for mydisease
# set()
# Could not summarize the following for myvariant
# {'dbnsfp.linsight.rankscore', 'dbnsfp.hg38.start', 'dbnsfp.fitcons.h1-hesc.confidence_value', 'dbnsfp.deogen2.score', 'dbnsfp.exac_nontcga.amr.af', 'dbnsfp.exac_nontcga.adj_af', 'dbnsfp.eve.score', 'dbnsfp.gtex.eqtl.gene', 'dbnsfp.exac_nonpsych.af', 'dbnsfp.exac_nonpsych.afr.ac', 'dbnsfp.fitcons.h1-hesc.score', 'dbnsfp.exac.sas.af', 'dbnsfp.exac_nonpsych.fin.ac', 'dbnsfp.m-cap.pred', 'dbnsfp.eve.class90_pred', 'dbnsfp.exac_nonpsych.eas.af', 'dbnsfp.eigen.raw_coding', 'dbnsfp.exac_nontcga.amr.ac', 'dbnsfp.exac_nontcga.afr.ac', 'dbnsfp.mutpred.aa_change', 'dbnsfp.phastcons.470way_mammalian.rankscore', 'dbnsfp.esm1b.pred', 'dbnsfp.phastcons.17way_primate.rankscore', 'dbnsfp.exac.ac', 'dbnsfp.hgvsc', 'dbnsfp.exac_nontcga.ac', 'dbnsfp.geuvadis_eqtl_target_gene', 'dbnsfp.exac.fin.af', 'dbnsfp.exac.sas.ac', 'dbnsfp.mutationtaster.analysis.model', 'dbnsfp.hg38.end', 'dbnsfp.mutationtaster.analysis.aae', 'dbnsfp.phastcons.470way_mammalian.score', 'dbnsfp.metasvm.rankscore', 'dbnsfp.metarnn.score', 'dbnsfp.eve.class50_pred', 'dbnsfp.mpc.score', 'dbnsfp.exac_nonpsych.adj_af', 'dbnsfp.metarnn.rankscore', 'dbnsfp.dann.score', 'dbnsfp.gtex.eqtl.tissue', 'dbnsfp.exac.adj_af', 'dbnsfp.exac.eas.ac', 'dbnsfp.eqtlgen.gene_id', 'dbnsfp.exac_nonpsych.nfe.ac', 'dbnsfp.eve.class75_pred', 'dbnsfp.mutpred.score', 'dbnsfp.mutationassessor.rankscore', 'dbnsfp.m-cap.rankscore', 'dbnsfp.mpc.rankscore', 'dbnsfp.hgvsp', 'dbnsfp.eigen-pc.phred_coding', 'dbnsfp.eve.rankscore', 'dbnsfp.hg19.end', 'dbnsfp.exac_nontcga.eas.ac', 'dbnsfp.eigen-pc.raw_coding', 'dbnsfp.ensembl.transcriptid', 'dbnsfp.eve.class20_pred', 'dbnsfp.eve.class25_pred', 'dbnsfp.hg18.start', 'dbnsfp.exac.amr.ac', 'dbnsfp.ensembl.geneid', 'dbnsfp.eve.class10_pred', 'dbnsfp.gmvp.score', 'dbnsfp.exac.nfe.ac', 'dbnsfp.phylop.100way_vertebrate.score', 'dbnsfp.phastcons.100way_vertebrate.score', 'dbnsfp.metarnn.pred', 'dbnsfp.eve.class60_pred', 'dbnsfp.gtex.sqtl.gene', 'dbnsfp.phylop.100way_vertebrate.rankscore', 'dbnsfp.lrt.omega', 'dbnsfp.esm1b.rankscore', 'dbnsfp.fitcons.huvec.score', 'dbnsfp.mutpred.accession', 'dbnsfp.lrt.converted_rankscore', 'dbnsfp.list-s2.rankscore', 'dbnsfp.exac_nonpsych.amr.af', 'dbnsfp.esp6500.aa.ac', 'dbnsfp.deogen2.pred', 'dbnsfp.fathmm-mkl.coding_score', 'dbnsfp.fathmm-xf.coding_pred', 'dbnsfp.fitcons.gm12878.confidence_value', 'dbnsfp.fitcons.h1-hesc.rankscore', 'dbnsfp.fitcons.integrated.score', 'dbnsfp.fathmm-mkl.coding_pred', 'dbnsfp.gmvp.rankscore', 'dbnsfp.denisova', 'dbnsfp.eve.class30_pred', 'dbnsfp.phylop.17way_primate.rankscore', 'dbnsfp.metalr.rankscore', 'dbnsfp.eqtlgen.snp_id', 'dbnsfp.mvp.rankscore', 'dbnsfp.exac.nfe.af', 'dbnsfp.hg19.start', 'dbnsfp.phastcons.100way_vertebrate.rankscore', 'dbnsfp.fathmm-mkl.coding_group', 'dbnsfp.mutationassessor.pred', 'dbnsfp.metasvm.pred', 'dbnsfp.eigen.raw_coding_rankscore', 'dbnsfp.esp6500.ea.ac', 'dbnsfp.eve.class70_pred', 'dbnsfp.exac_nontcga.adj_ac', 'dbnsfp.exac_nonpsych.nfe.af', 'dbnsfp.fitcons.integrated.rankscore', 'dbnsfp.exac_nonpsych.ac', 'dbnsfp.exac_nonpsych.adj_ac', 'dbnsfp.mutpred.pred.mechanism', 'dbnsfp.metalr.pred', 'dbnsfp.exac_nonpsych.afr.af', 'dbnsfp.esp6500.aa.af', 'dbnsfp.fitcons.gm12878.rankscore', 'dbnsfp.exac_nonpsych.amr.ac', 'dbnsfp.exac_nonpsych.eas.ac', 'dbnsfp.mutpred.pred.p_val', 'dbnsfp.exac_nonpsych.fin.af', 'dbnsfp.mutationtaster.analysis.score', 'dbnsfp.fitcons.huvec.rankscore', 'dbnsfp.genename', 'dbnsfp.exac.amr.af', 'dbnsfp.lrt.pred', 'dbnsfp.mutationtaster.analysis.pred', 'dbnsfp.phastcons.17way_primate.score', 'dbnsfp.gerp++.rs_rankscore', 'dbnsfp.exac.adj_ac', 'dbnsfp.gtex.sqtl.tissue', 'dbnsfp.genocanyon.score', 'dbnsfp.gerp++.rs', 'dbnsfp.lrt.score', 'dbnsfp.esp6500.ea.af', 'dbnsfp.dann.rankscore', 'dbnsfp.eqtlgen.cis_or_trans', 'dbnsfp.mutpred.rankscore', 'dbnsfp.esm1b.score', 'dbnsfp.fitcons.huvec.confidence_value', 'dbnsfp.eigen-pc.raw_coding_rankscore', 'dbnsfp.mutationassessor.score', 'dbnsfp.linsight.score', 'dbnsfp.exac.afr.ac', 'dbnsfp.fathmm-xf.coding_score', 'd ...

# %%
import pandas as pd

for api_name in schemas:
    df = pd.DataFrame(schema_desc[api_name], columns=["field", "description"])
    df.to_csv(f"data/schema/{api_name}_field_desc.csv", index=False)
